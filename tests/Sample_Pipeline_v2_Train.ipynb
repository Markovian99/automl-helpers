# %% [markdown]
# ## AutoML Process
# ###  1) Read data
# ###  2) Determine numeric, categorical, and text
# ###  3) Define partitioning method and CV method
# ###  4) Build out the pipeline on training data
# ### &nbsp;&nbsp;  4a) Transform Categorical Data using ordinal (frequency or alphabetical) other encoding such as binary one-hot
# ### &nbsp;&nbsp;  4b) Model Stacking on Text Data using tf-idf+ElasticNet - replace empty with nan
# ### &nbsp;&nbsp;  4c) Missing numerical: for tree set as large number outside of range (maybe pick side based on correlation)
# ###  5) Definte gridsearch
# ###  6) Estimate model and test
# ###  7) Save as .pkl file

# %%
from copy import copy

import numpy as np
from numpy import inf
import pandas as pd
from datetime import datetime
import functools
import matplotlib.pyplot as plt  

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn import svm 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier  #RF and GBM algorithm
from sklearn.linear_model import ElasticNet, SGDClassifier
from sklearn.model_selection import GridSearchCV   #Perforing grid search
from sklearn import preprocessing, neighbors, metrics
import sklearn
if sklearn.__version__<'0.20':
    from sklearn.cross_validation import train_test_split, KFold, StratifiedKFold, PredefinedSplit
else:
    from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, PredefinedSplit

import scipy.stats as st
from sklearn.metrics import mean_absolute_error, accuracy_score, log_loss, make_scorer, auc, roc_auc_score


# %matplotlib inline
# Out:
# /tmp/ipykernel_254863/4199328548.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import automl
from automl import StackLayer, TextElasticNetBinary, MissingDataHandler

# %%
# import importlib
# importlib.reload(automl)

# %%
#https://www.hindawi.com/journals/bmri/2014/781670/
input_data=pd.read_csv("diabetes_data.csv")
input_data.sample(5)
# Out:
#       rowID             race  gender      age    weight admission_type_id  \
# 2661   2662        Caucasian  Female  [50-60)         ?         Emergency
# 3695   3696        Caucasian  Female  [80-90)  [75-100)         Emergency
# 5104   5105        Caucasian    Male  [50-60)         ?         Emergency
# 4188   4189        Caucasian  Female  [70-80)         ?            Urgent
# 8010   8011  AfricanAmerican  Female  [80-90)         ?         Emergency
#
#                                discharge_disposition_id admission_source_id  \
# 2661                                 Discharged to home      Emergency Room
# 3695                                     Hospice / home      Emergency Room
# 5104                                           Left AMA      Emergency Room
# 4188                                 Discharged to home  Physician Referral
# 8010  Discharged/transferred to home with home healt...      Emergency Room
#
#       time_in_hospital payer_code  ... glipizide.metformin  \
# 2661                 7          ?  ...                  No
# 3695                 6         MC  ...                  No
# 5104                 2         MD  ...                  No
# 4188                 3          ?  ...                  No
# 8010                 5          ?  ...                  No
#
#       glimepiride.pioglitazone  metformin.rosiglitazone  \
# 2661                        No                       No
# 3695                        No                       No
# 5104                        No                       No
# 4188                        No                       No
# 8010                        No                       No
#
#       metformin.pioglitazone  change  diabetesMed  readmitted  \
# 2661                      No      No           No        True
# 3695                      No      No           No       False
# 5104                      No      Ch          Yes        True
# 4188                      No      No          Yes        True
# 8010                      No      No          Yes       False
#
#                                             diag_1_desc  \
# 2661          Acute vascular insufficiency of intestine
# 3695  Acute myocardial infarction of anterolateral w...
# 5104              Congestive heart failure, unspecified
# 4188                    Pneumonia, organism unspecified
# 8010               Hyperosmolality and/or hypernatremia
#
#                                             diag_2_desc  \
# 2661              Congestive heart failure, unspecified
# 3695  Hypertensive chronic kidney disease, malignant...
# 5104  Acute myocardial infarction of anterolateral w...
# 4188  Pleurisy without mention of effusion or curren...
# 8010              Congestive heart failure, unspecified
#
#                                             diag_3_desc
# 2661                    Pneumonia, organism unspecified
# 3695                       Chronic kidney disease (ckd)
# 5104  Hypertensive chronic kidney disease, malignant...
# 4188    Mitral valve stenosis and aortic valve stenosis
# 8010            Paroxysmal supraventricular tachycardia
#
# [5 rows x 52 columns]

# %%
print(input_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rowID                     10000 non-null  int64
#  1   race                      10000 non-null  object
#  2   gender                    10000 non-null  object
#  3   age                       10000 non-null  object
#  4   weight                    10000 non-null  object
#  5   admission_type_id         9279 non-null   object
#  6   discharge_disposition_id  9531 non-null   object
#  7   admission_source_id       9064 non-null   object
#  8   time_in_hospital          10000 non-null  int64
#  9   payer_code                10000 non-null  object
#  10  medical_specialty         10000 non-null  object
#  11  num_lab_procedures        10000 non-null  int64
#  12  num_procedures            10000 non-null  int64
#  13  num_medications           10000 non-null  int64
#  14  number_outpatient         10000 non-null  int64
#  15  number_emergency          10000 non-null  int64
#  16  number_inpatient          10000 non-null  int64
#  17  diag_1                    10000 non-null  object
#  18  diag_2                    10000 non-null  object
#  19  diag_3                    10000 non-null  object
#  20  number_diagnoses          10000 non-null  int64
#  21  max_glu_serum             664 non-null    object
#  22  A1Cresult                 1621 non-null   object
#  23  metformin                 10000 non-null  object
#  24  repaglinide               10000 non-null  object
#  25  nateglinide               10000 non-null  object
#  26  chlorpropamide            10000 non-null  object
#  27  glimepiride               10000 non-null  object
#  28  acetohexamide             10000 non-null  object
#  29  glipizide                 10000 non-null  object
#  30  glyburide                 10000 non-null  object
#  31  tolbutamide               10000 non-null  object
#  32  pioglitazone              10000 non-null  object
#  33  rosiglitazone             10000 non-null  object
#  34  acarbose                  10000 non-null  object
#  35  miglitol                  10000 non-null  object
#  36  troglitazone              10000 non-null  object
#  37  tolazamide                10000 non-null  object
#  38  examide                   10000 non-null  object
#  39  citoglipton               10000 non-null  object
#  40  insulin                   10000 non-null  object
#  41  glyburide.metformin       10000 non-null  object
#  42  glipizide.metformin       10000 non-null  object
#  43  glimepiride.pioglitazone  10000 non-null  object
#  44  metformin.rosiglitazone   10000 non-null  object
#  45  metformin.pioglitazone    10000 non-null  object
#  46  change                    10000 non-null  object
#  47  diabetesMed               10000 non-null  object
#  48  readmitted                10000 non-null  bool
#  49  diag_1_desc               9998 non-null   object
#  50  diag_2_desc               9941 non-null   object
#  51  diag_3_desc               9792 non-null   object
# dtypes: bool(1), int64(9), object(42)
# memory usage: 3.9+ MB
# None

# %%
input_data.describe().T
# Out:
#                       count       mean          std  min      25%     50%  \
# rowID               10000.0  5000.5000  2886.895680  1.0  2500.75  5000.5
# time_in_hospital    10000.0     4.4347     3.021597  1.0     2.00     4.0
# num_lab_procedures  10000.0    43.0786    19.453315  1.0    32.00    44.0
# num_procedures      10000.0     1.3992     1.706438  0.0     0.00     1.0
# num_medications     10000.0    15.5638     8.391613  1.0    10.00    14.0
# number_outpatient   10000.0     0.2817     1.119406  0.0     0.00     0.0
# number_emergency    10000.0     0.1150     0.649475  0.0     0.00     0.0
# number_inpatient    10000.0     0.3873     0.854267  0.0     0.00     0.0
# number_diagnoses    10000.0     7.0253     2.020957  1.0     5.00     7.0
#
#                         75%      max
# rowID               7500.25  10000.0
# time_in_hospital       6.00     14.0
# num_lab_procedures    57.00    120.0
# num_procedures         2.00      6.0
# num_medications       19.00     81.0
# number_outpatient      0.00     36.0
# number_emergency       0.00     42.0
# number_inpatient       0.00     10.0
# number_diagnoses       9.00      9.0

# %%
target='readmitted'
feature_list=['number_inpatient','num_medications','time_in_hospital','num_procedures','number_outpatient','number_emergency',
              'discharge_disposition_id','medical_specialty',"number_diagnoses","num_lab_procedures","admission_source_id",
              'age', 'diag_1_desc','diag_2_desc',"diag_3_desc",'admission_type_id']#'diag_1',"diag_2","diag_3"
num_features=['number_inpatient', 'number_diagnoses','num_lab_procedures','num_medications','time_in_hospital','num_procedures','number_outpatient','number_emergency']
text_features=list(set(feature_list)^set(num_features))
text_features
# Out:
# ['medical_specialty',
#  'admission_source_id',
#  'diag_1_desc',
#  'admission_type_id',
#  'diag_2_desc',
#  'discharge_disposition_id',
#  'age',
#  'diag_3_desc']

# %%
X=input_data[feature_list]
y=input_data[target].astype(int)

# %% [markdown]
# # Define partioning method and CV method

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
#split the data into 5 time cross validation folds
ps = PredefinedSplit(test_fold=np.floor(5*np.arange(len(X_train))/len(X_train)))
ps.unique_folds
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# # Define preprocessing based on train

# %%
feature_lists_2=[]
drop_text_list=[]
sss=[]

for feat in list(text_features):    
    print(feat)
    if X_train[feat].nunique()>1:
        feature_lists_2.append(feat)
        sss_temp=StackLayer(models=[TextElasticNetBinary(token_pattern=r'(?u)\b\w+\b')],feature_lists=[feat], gridsearch_lists=[{'penalty_C':list(np.arange(1,10.1,4)),'ngram_range':list([(1, 1),(1,2)])}],regression=False,verbose=0)
        sss_temp.tune_hyperparameters(X_train, y_train, metric=None, n_jobs=1, cv=ps)
        sss.append(sss_temp)
    else:
        print("Not unique values for "+feat)
        drop_text_list.append([feat])
# Out:
# medical_specialty
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# admission_source_id
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# diag_1_desc
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# admission_type_id
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# diag_2_desc
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# discharge_disposition_id
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# age
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# diag_3_desc
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
feature_lists_2
# Out:
# ['medical_specialty',
#  'admission_source_id',
#  'diag_1_desc',
#  'admission_type_id',
#  'diag_2_desc',
#  'discharge_disposition_id',
#  'age',
#  'diag_3_desc']

# %%
mmm=MissingDataHandler(method='median',create_dummy=True)
gbm=GradientBoostingClassifier(learning_rate=.05,random_state=1234)

# %%
pipe = Pipeline(
    [   ("Preprocessing",ColumnTransformer([( "MissingNumeric", mmm, num_features)]+[("TextStacking_#"+feature_lists_2[fff], sss[fff], [feature_lists_2[fff]]) for fff in range(len(feature_lists_2))],remainder='passthrough')),
        # Use a SVC classifier on the combined features
        ("gbm", gbm),
    ],
    verbose=True,
)

# %%
# # Optimize entire pipeline over and over - INEFFICEINT
# models_2=[TextElasticNetBinary(token_pattern=r'(?u)\b\w+\b')]
# gridsearch_lists_2=[{'penalty_C':list(np.arange(1,10.1,4)),'ngram_range':list([(1, 1),(1,2)])}]
# sss=StackLayer(models=models_2,gridsearch_lists=gridsearch_lists_2,regression=False,verbose=1)
# pipe = Pipeline(
#     [   ("Preprocessing",ColumnTransformer([( "MissingNumeric", mmm, num_features)]+[("TextStacking_#"+fff, copy(sss), [fff]) for fff in feature_lists_2],remainder='passthrough')),
#         # Use a SVC classifier on the combined features
#         ("gbm", gbm),
#     ],
#     verbose=True,
# )

# %%
# pipe = Pipeline(
#     [   ("Preprocessing",ColumnTransformer([( "MissingNumeric", mmm, num_features),("Text",sss,['diag_1_desc'])])),
#         ("gbm", gbm),
#     ],
#     verbose=True,
# )

# %%
len(feature_lists_2)
# Out:
# 8

# %%
[sss1.autotune for sss1 in sss]
# Out:
# [False, False, False, False, False, False, False, False]

# %%
# pipe.fit(X_train[num_features+[fff[0] for fff in feature_lists_2]], y_train)

# %%
param_grid = {
    "gbm__n_estimators": list(range(100,201,100)),
    'gbm__max_depth':list(range(3,6,2))
}
search = GridSearchCV(pipe, param_grid, n_jobs=None,verbose=1)
search.fit(X_train[num_features+[fff for fff in feature_lists_2]], y_train)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.1min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.8s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.8min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.8s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.0min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.8s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.2min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.8s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.1min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.8s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.0min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.5s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.8min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.5s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.0min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.6s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.2min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.6s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.0min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.6s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.0min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.4s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.9min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.3s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.1min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.4s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.2min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.3s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.1min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.4s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.0min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   2.6s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.9min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   2.6s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.1min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   2.6s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.2min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   2.5s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.0min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   2.5s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 2.8min
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.6s
# Best parameter (CV score=0.657):
# {'gbm__max_depth': 5, 'gbm__n_estimators': 100}

# %%
search.cv_results_['mean_test_score'], search.best_params_, search.best_score_, search.best_estimator_
# Out:
# (array([0.65425 , 0.656   , 0.657125, 0.653125]),
#  {'gbm__max_depth': 5, 'gbm__n_estimators': 100},
#  0.6571250000000001,
#  Pipeline(steps=[('Preprocessing',
#                   ColumnTransformer(remainder='passthrough',
#                                     transformers=[('MissingNumeric',
#                                                    MissingDataHandler(columns=[],
#                                                                       create_dummy=True,
#                                                                       imputation_funcs=[],
#                                                                       imputation_values=[],
#                                                                       method='median'),
#                                                    ['number_inpatient',
#                                                     'number_diagnoses',
#                                                     'num_lab_procedures',
#                                                     'num_medications',
#                                                     'time_in_hospital',
#                                                     'num_procedures',
#                                                     'number_outpatient',
#                                                     'nu...
#                                                   ('TextStacking_#diag_3_desc',
#                                                    StackLayer(feature_lists=['diag_3_desc'],
#                                                               gridsearch_lists=[{'ngram_range': [(1,
#                                                                                                   1),
#                                                                                                  (1,
#                                                                                                   2)],
#                                                                                  'penalty_C': [1.0,
#                                                                                                5.0,
#                                                                                                9.0]}],
#                                                               models=[TextElasticNetBinary(ngram_range=(1,
#                                                                                                         2),
#                                                                                            penalty_C=9.0,
#                                                                                            token_pattern='(?u)\\b\\w+\\b')]),
#                                                    ['diag_3_desc'])])),
#                  ('gbm',
#                   GradientBoostingClassifier(learning_rate=0.05, max_depth=5,
#                                              random_state=1234))],
#           verbose=True))

# %%
final_layer=search.best_estimator_[-1]
final_layer
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_depth=5, random_state=1234)

# %%
for c in range(len(final_layer.feature_importances_)):
    print(X_train[num_features+[fff for fff in feature_lists_2]].columns[c]+": "+str(final_layer.feature_importances_[c]))
# Out:
# number_inpatient: 0.1745032239770585
# number_diagnoses: 0.0695767621912206
# num_lab_procedures: 0.07101988209868798
# num_medications: 0.040068094096367184
# time_in_hospital: 0.025038865204598998
# num_procedures: 0.0115267736914375
# number_outpatient: 0.036028471897355495
# number_emergency: 0.018557602001610187
# medical_specialty: 0.07759779306783127
# admission_source_id: 0.04211609448213232
# diag_1_desc: 0.07751141399755976
# admission_type_id: 0.038723585294654334
# diag_2_desc: 0.053856869023289795
# discharge_disposition_id: 0.14352104912550104
# age: 0.05542311167376319
# diag_3_desc: 0.06493040817693188

# %%
X_test[num_features+[fff for fff in feature_lists_2]]
# Out:
#       number_inpatient  number_diagnoses  num_lab_procedures  num_medications  \
# 2374                 0                 9                  62               40
# 1784                 0                 5                   1               16
# 6301                 0                 9                  54               14
# 1600                 0                 5                  45               36
# 7920                 1                 9                  53               14
# ...                ...               ...                 ...              ...
# 8623                 0                 9                   4               13
# 5928                 0                 9                  50               15
# 6714                 0                 6                  64               13
# 5885                 0                 7                  25                7
# 7289                 0                 7                  45               16
#
#       time_in_hospital  num_procedures  number_outpatient  number_emergency  \
# 2374                14               6                  0                 0
# 1784                 3               3                  6                 0
# 6301                 7               0                  0                 0
# 1600                 4               5                  0                 0
# 7920                12               0                  0                 0
# ...                ...             ...                ...               ...
# 8623                 1               0                  0                 0
# 5928                 3               0                  0                 0
# 6714                 3               0                  0                 0
# 5885                 3               0                  0                 0
# 7289                14               2                  0                 0
#
#      medical_specialty                             admission_source_id  \
# 2374  InternalMedicine                                  Emergency Room
# 1784                 ?                                             NaN
# 6301  InternalMedicine                                  Emergency Room
# 1600                 ?                              Physician Referral
# 7920                 ?      Transfer from another health care facility
# ...                ...                                             ...
# 8623                 ?                                  Emergency Room
# 5928                 ?                                  Emergency Room
# 6714                 ?                                  Emergency Room
# 5885  Emergency/Trauma                                  Emergency Room
# 7289                 ?  Transfer from a Skilled Nursing Facility (SNF)
#
#                                             diag_1_desc admission_type_id  \
# 2374  Diabetes with ketoacidosis, type II or unspeci...         Emergency
# 1784                               Obesity, unspecified     Not Available
# 6301                          Simple chronic bronchitis         Emergency
# 1600  Coronary atherosclerosis of unspecified type o...          Elective
# 7920                 Care involving breathing exercises          Elective
# ...                                                 ...               ...
# 8623               Respiratory abnormality, unspecified         Emergency
# 5928                           Streptococcal septicemia            Urgent
# 6714  Acute myocardial infarction of anterolateral w...         Emergency
# 5885            Paroxysmal supraventricular tachycardia          Elective
# 7289                           Atherosclerosis of aorta         Emergency
#
#                                             diag_2_desc  \
# 2374            Paroxysmal supraventricular tachycardia
# 1784                          Pure hypercholesterolemia
# 6301  Coronary atherosclerosis of unspecified type o...
# 1600                 Postmyocardial infarction syndrome
# 7920  Cerebral thrombosis without mention of cerebra...
# ...                                                 ...
# 8623        Urinary tract infection, site not specified
# 5928                               Acute kidney failure
# 6714              Congestive heart failure, unspecified
# 5885                           Acute laryngopharyngitis
# 7289              Acute osteomyelitis, site unspecified
#
#                                discharge_disposition_id      age  \
# 2374                                 Discharged to home  [40-50)
# 1784                                 Discharged to home  [50-60)
# 6301  Discharged/transferred to another  type of inp...  [80-90)
# 1600                                                NaN  [50-60)
# 7920  Discharged/transferred to home with home healt...  [60-70)
# ...                                                 ...      ...
# 8623                      Discharged/transferred to ICF  [70-80)
# 5928  Discharged/transferred to another short term h...  [60-70)
# 6714                      Discharged/transferred to SNF  [80-90)
# 5885                                 Discharged to home  [50-60)
# 7289                      Discharged/transferred to SNF  [50-60)
#
#                                             diag_3_desc
# 2374                                 Pulmonary collapse
# 1784                   Malignant essential hypertension
# 6301  Coronary atherosclerosis of unspecified type o...
# 1600  Diabetes mellitus without mention of complicat...
# 7920                           Cerebral atherosclerosis
# ...                                                 ...
# 8623                                           Headache
# 5928  Hypertensive chronic kidney disease, malignant...
# 6714                        Alteration of consciousness
# 5885                        Chronic maxillary sinusitis
# 7289                   Pressure ulcer, unspecified site
#
# [2000 rows x 16 columns]

# %%
#get test set text predictions
test_pred=search.predict_proba(X_test[num_features+[fff for fff in feature_lists_2]])

# %%
test_pred=search.best_estimator_.predict_proba(X_test[num_features+[fff for fff in feature_lists_2]])

# %%
# X_test_final=pd.concat([X_test[num_features],pd.DataFrame(test_pred,columns=text_features,index=X_test.index)],axis=1)

# %%
roc_auc_score(y_test,test_pred[:,1])
# Out:
# 0.6983620102322787

# %%
log_loss(y_test, test_pred[:,1])
# Out:
# 0.6078153539836869

# %%
#model much better than text aalone
# print(log_loss(y_test, test_pred[:,0]))
# print(log_loss(y_test, test_pred[:,1]))
# log_loss(y_test, test_pred[:,2])

# %%
type(search.best_estimator_)
# Out:
# sklearn.pipeline.Pipeline

# %%
# import sklearn.external.joblib as extjoblib
import joblib

joblib.dump(search.best_estimator_, 'pipeline.pkl')
# Out:
# ['pipeline.pkl']
