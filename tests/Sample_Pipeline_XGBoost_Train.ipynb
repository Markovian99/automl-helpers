# %% [markdown]
# ## AutoML Process
# ###  1) Read data
# ###  2) Determine numeric, categorical, and text
# ###  3) Define partitioning method and CV method
# ###  4) Build out the pipeline on training data
# ### &nbsp;&nbsp;  4a) Transform Categorical Data using ordinal (frequency or alphabetical) other encoding such as binary one-hot
# ### &nbsp;&nbsp;  4b) Model Stacking on Text Data using tf-idf+ElasticNet - replace empty with nan
# ### &nbsp;&nbsp;  4c) Missing numerical: for tree set as large number outside of range (maybe pick side based on correlation)
# ###  5) Definte gridsearch
# ###  6) Estimate model and test
# ###  7) Save as .pkl file

# %%
from copy import copy

import numpy as np
from numpy import inf
import pandas as pd
from datetime import datetime
import functools
import matplotlib.pyplot as plt  

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn import svm 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier  #RF and GBM algorithm
from sklearn.linear_model import ElasticNet, SGDClassifier
from sklearn.model_selection import GridSearchCV   #Perforing grid search
from sklearn import preprocessing, neighbors, metrics
import sklearn
if sklearn.__version__<'0.20':
    from sklearn.cross_validation import train_test_split, KFold, StratifiedKFold, PredefinedSplit
else:
    from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, PredefinedSplit

import scipy.stats as st
from sklearn.metrics import mean_absolute_error, accuracy_score, log_loss, make_scorer, auc, roc_auc_score

import joblib
import yaml

import xgboost as xgb

# %matplotlib inline

# %%
import automl
from automl import StackLayer, TextElasticNetBinary, MissingDataHandler

# %%
# import importlib
# importlib.reload(automl)

# %%
#https://www.hindawi.com/journals/bmri/2014/781670/
input_data=pd.read_csv("diabetes_data.csv")
input_data.sample(5)
# Out:
#       rowID       race  gender       age weight admission_type_id  \
# 6982   6983  Caucasian    Male   [80-90)      ?         Emergency
# 7195   7196  Caucasian    Male   [60-70)      ?            Urgent
# 9453   9454  Caucasian    Male   [30-40)      ?            Urgent
# 1200   1201  Caucasian  Female   [60-70)      ?          Elective
# 7670   7671  Caucasian    Male  [90-100)      ?          Elective
#
#                                discharge_disposition_id admission_source_id  \
# 6982                                 Discharged to home      Emergency Room
# 7195                                 Discharged to home      Emergency Room
# 9453                                 Discharged to home  Physician Referral
# 1200  Discharged/transferred to home with home healt...  Physician Referral
# 7670                                                NaN  Physician Referral
#
#       time_in_hospital payer_code  ... glipizide.metformin  \
# 6982                 4          ?  ...                  No
# 7195                 2         MC  ...                  No
# 9453                 1          ?  ...                  No
# 1200                 5          ?  ...                  No
# 7670                 4          ?  ...                  No
#
#       glimepiride.pioglitazone  metformin.rosiglitazone  \
# 6982                        No                       No
# 7195                        No                       No
# 9453                        No                       No
# 1200                        No                       No
# 7670                        No                       No
#
#       metformin.pioglitazone  change  diabetesMed  readmitted  \
# 6982                      No      Ch          Yes        True
# 7195                      No      Ch          Yes        True
# 9453                      No      No           No        True
# 1200                      No      Ch          Yes       False
# 7670                      No      No           No       False
#
#                                             diag_1_desc  \
# 6982              Congestive heart failure, unspecified
# 7195  Diabetes mellitus without mention of complicat...
# 9453  Mechanical complication of unspecified cardiac...
# 1200  Coronary atherosclerosis of unspecified type o...
# 7670              Congestive heart failure, unspecified
#
#                                             diag_2_desc  \
# 6982  Hypertensive chronic kidney disease, malignant...
# 7195                          Pure hypercholesterolemia
# 9453                       Chronic kidney disease (ckd)
# 1200                               Sideroblastic anemia
# 7670  Chronic airway obstruction, not elsewhere clas...
#
#                                             diag_3_desc
# 6982  Chronic airway obstruction, not elsewhere clas...
# 7195                   Malignant essential hypertension
# 9453  Diabetes mellitus without mention of complicat...
# 1200      Osteoarthrosis, generalized, site unspecified
# 7670  Diabetes mellitus without mention of complicat...
#
# [5 rows x 52 columns]

# %%
print(input_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rowID                     10000 non-null  int64
#  1   race                      10000 non-null  object
#  2   gender                    10000 non-null  object
#  3   age                       10000 non-null  object
#  4   weight                    10000 non-null  object
#  5   admission_type_id         9279 non-null   object
#  6   discharge_disposition_id  9531 non-null   object
#  7   admission_source_id       9064 non-null   object
#  8   time_in_hospital          10000 non-null  int64
#  9   payer_code                10000 non-null  object
#  10  medical_specialty         10000 non-null  object
#  11  num_lab_procedures        10000 non-null  int64
#  12  num_procedures            10000 non-null  int64
#  13  num_medications           10000 non-null  int64
#  14  number_outpatient         10000 non-null  int64
#  15  number_emergency          10000 non-null  int64
#  16  number_inpatient          10000 non-null  int64
#  17  diag_1                    10000 non-null  object
#  18  diag_2                    10000 non-null  object
#  19  diag_3                    10000 non-null  object
#  20  number_diagnoses          10000 non-null  int64
#  21  max_glu_serum             664 non-null    object
#  22  A1Cresult                 1621 non-null   object
#  23  metformin                 10000 non-null  object
#  24  repaglinide               10000 non-null  object
#  25  nateglinide               10000 non-null  object
#  26  chlorpropamide            10000 non-null  object
#  27  glimepiride               10000 non-null  object
#  28  acetohexamide             10000 non-null  object
#  29  glipizide                 10000 non-null  object
#  30  glyburide                 10000 non-null  object
#  31  tolbutamide               10000 non-null  object
#  32  pioglitazone              10000 non-null  object
#  33  rosiglitazone             10000 non-null  object
#  34  acarbose                  10000 non-null  object
#  35  miglitol                  10000 non-null  object
#  36  troglitazone              10000 non-null  object
#  37  tolazamide                10000 non-null  object
#  38  examide                   10000 non-null  object
#  39  citoglipton               10000 non-null  object
#  40  insulin                   10000 non-null  object
#  41  glyburide.metformin       10000 non-null  object
#  42  glipizide.metformin       10000 non-null  object
#  43  glimepiride.pioglitazone  10000 non-null  object
#  44  metformin.rosiglitazone   10000 non-null  object
#  45  metformin.pioglitazone    10000 non-null  object
#  46  change                    10000 non-null  object
#  47  diabetesMed               10000 non-null  object
#  48  readmitted                10000 non-null  bool
#  49  diag_1_desc               9998 non-null   object
#  50  diag_2_desc               9941 non-null   object
#  51  diag_3_desc               9792 non-null   object
# dtypes: bool(1), int64(9), object(42)
# memory usage: 3.9+ MB
# None

# %%
input_data.describe().T
# Out:
#                       count       mean          std  min      25%     50%  \
# rowID               10000.0  5000.5000  2886.895680  1.0  2500.75  5000.5
# time_in_hospital    10000.0     4.4347     3.021597  1.0     2.00     4.0
# num_lab_procedures  10000.0    43.0786    19.453315  1.0    32.00    44.0
# num_procedures      10000.0     1.3992     1.706438  0.0     0.00     1.0
# num_medications     10000.0    15.5638     8.391613  1.0    10.00    14.0
# number_outpatient   10000.0     0.2817     1.119406  0.0     0.00     0.0
# number_emergency    10000.0     0.1150     0.649475  0.0     0.00     0.0
# number_inpatient    10000.0     0.3873     0.854267  0.0     0.00     0.0
# number_diagnoses    10000.0     7.0253     2.020957  1.0     5.00     7.0
#
#                         75%      max
# rowID               7500.25  10000.0
# time_in_hospital       6.00     14.0
# num_lab_procedures    57.00    120.0
# num_procedures         2.00      6.0
# num_medications       19.00     81.0
# number_outpatient      0.00     36.0
# number_emergency       0.00     42.0
# number_inpatient       0.00     10.0
# number_diagnoses       9.00      9.0

# %%
target='readmitted'
feature_list=['number_inpatient','num_medications','time_in_hospital','num_procedures','number_outpatient','number_emergency',
              'discharge_disposition_id','medical_specialty',"number_diagnoses","num_lab_procedures","admission_source_id",
              'age', 'diag_1_desc','diag_2_desc',"diag_3_desc",'admission_type_id']#'diag_1',"diag_2","diag_3"
num_features=['number_inpatient', 'number_diagnoses','num_lab_procedures','num_medications','time_in_hospital','num_procedures','number_outpatient','number_emergency']
text_features=list(set(feature_list)^set(num_features))
text_features
# Out:
# ['medical_specialty',
#  'admission_source_id',
#  'diag_3_desc',
#  'diag_1_desc',
#  'admission_type_id',
#  'diag_2_desc',
#  'age',
#  'discharge_disposition_id']

# %%
X=input_data[feature_list]
y=input_data[target].astype(int)

# %% [markdown]
# # Define partioning method and CV method

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
#split the data into 5 time cross validation folds
ps = PredefinedSplit(test_fold=np.floor(5*np.arange(len(X_train))/len(X_train)))
ps.unique_folds
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# # Define preprocessing based on train

# %%
feature_lists_2=[]
drop_text_list=[]
sss=[]

for feat in list(text_features):    
    print(feat)
    if X_train[feat].nunique()>1:
        feature_lists_2.append(feat)
        sss_temp=StackLayer(models=[TextElasticNetBinary(token_pattern=r'(?u)\b\w+\b')],feature_lists=[feat], gridsearch_lists=[{'penalty_C':list(np.arange(1,10.1,4)),'ngram_range':list([(1, 1),(1,2)])}],regression=False,verbose=0)
        sss_temp.tune_hyperparameters(X_train, y_train, metric=None, n_jobs=1, cv=ps)
        sss.append(sss_temp)
    else:
        print("Not unique values for "+feat)
        drop_text_list.append([feat])
# Out:
# medical_specialty
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# admission_source_id
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# diag_3_desc
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# diag_1_desc
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# admission_type_id
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# diag_2_desc
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# age
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# discharge_disposition_id
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
feature_lists_2
# Out:
# ['medical_specialty',
#  'admission_source_id',
#  'diag_3_desc',
#  'diag_1_desc',
#  'admission_type_id',
#  'diag_2_desc',
#  'age',
#  'discharge_disposition_id']

# %%
mmm=MissingDataHandler(method='median',create_dummy=True)
gbm=GradientBoostingClassifier(learning_rate=.05,random_state=1234)

#Fitting XGB regressor 
#model = xgb.XGBRegressor()
gbm = xgb.XGBClassifier(colsample_bylevel=1, colsample_bynode=1, colsample_bytree=.3, gamma=0,#0.005,
             importance_type='gain', learning_rate=0.05, max_delta_step=0,
             max_depth=3, min_child_weight=1, missing=-99999, n_estimators=300, random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
             silent=None, subsample=1, verbosity=1)

# %%
pipe = Pipeline(
    [   ("Preprocessing",ColumnTransformer([( "MissingNumeric", mmm, num_features)]+[("TextStacking_#"+feature_lists_2[fff], sss[fff], [feature_lists_2[fff]]) for fff in range(len(feature_lists_2))])),#,remainder='passthrough'
        # Use a SVC classifier on the combined features
        ("gbm", gbm),
    ],
    verbose=True,
)

# %%
# history = model.fit(train_x, train_y, eval_set=[(test_x, test_y)],early_stopping_rounds=25) 
# print("--- %s seconds ---" % (time.time() - start_time))
# print(history)
# print(model)

# %%
len(feature_lists_2)
# Out:
# 8

# %%
pipe_trf = Pipeline(pipe.steps[:-1])
params_fit={}
params_fit['gbm__eval_set'] = [(pipe_trf.fit_transform(X_train[num_features+[fff for fff in feature_lists_2]], y_train), y_train),
                                (pipe_trf.transform(pd.DataFrame(X_test[num_features+[fff for fff in feature_lists_2]])),
                                 y_test)]
params_fit['gbm__early_stopping_rounds'] = 10

# pipe = pipe.fit(X_train[num_features+[fff for fff in feature_lists_2]],y_train, **params_fit)
# Out:
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
pipe_trf.steps==pipe.steps[:-1]
# Out:
# True

# %%
param_grid = {
    'gbm__max_depth':list(range(3,5,1))
}
# params_fit['gbm__max_depth']=list(range(3,6,2))

# %%
search = GridSearchCV(pipe,param_grid=param_grid, n_jobs=2,verbose=1)
search.fit(X_train[num_features+[fff for fff in feature_lists_2]], y_train, **params_fit)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.2min
# [0]	validation_0-logloss:0.67181	validation_1-logloss:0.66489
# [1]	validation_0-logloss:0.66986	validation_1-logloss:0.66319
# [2]	validation_0-logloss:0.66859	validation_1-logloss:0.66202
# [3]	validation_0-logloss:0.66740	validation_1-logloss:0.66113
# [4]	validation_0-logloss:0.66586	validation_1-logloss:0.65962
# [5]	validation_0-logloss:0.66277	validation_1-logloss:0.65656
# [6]	validation_0-logloss:0.66163	validation_1-logloss:0.65532
# [7]	validation_0-logloss:0.66040	validation_1-logloss:0.65474
# [8]	validation_0-logloss:0.65899	validation_1-logloss:0.65373
# [9]	validation_0-logloss:0.65780	validation_1-logloss:0.65293
# [10]	validation_0-logloss:0.65596	validation_1-logloss:0.65131
# [11]	validation_0-logloss:0.65496	validation_1-logloss:0.65062
# [12]	validation_0-logloss:0.65421	validation_1-logloss:0.64990
# [13]	validation_0-logloss:0.65323	validation_1-logloss:0.64904
# [14]	validation_0-logloss:0.65225	validation_1-logloss:0.64825
# [15]	validation_0-logloss:0.65085	validation_1-logloss:0.64696
# [16]	validation_0-logloss:0.65024	validation_1-logloss:0.64644
# [17]	validation_0-logloss:0.64929	validation_1-logloss:0.64538
# [18]	validation_0-logloss:0.64864	validation_1-logloss:0.64496
# [19]	validation_0-logloss:0.64790	validation_1-logloss:0.64417
# [20]	validation_0-logloss:0.64530	validation_1-logloss:0.64173
# [21]	validation_0-logloss:0.64453	validation_1-logloss:0.64103
# [22]	validation_0-logloss:0.64299	validation_1-logloss:0.63971
# [23]	validation_0-logloss:0.64194	validation_1-logloss:0.63860
# [24]	validation_0-logloss:0.64120	validation_1-logloss:0.63793
# [25]	validation_0-logloss:0.64023	validation_1-logloss:0.63716
# [26]	validation_0-logloss:0.63975	validation_1-logloss:0.63666
# [27]	validation_0-logloss:0.63890	validation_1-logloss:0.63573
# [28]	validation_0-logloss:0.63822	validation_1-logloss:0.63529
# [29]	validation_0-logloss:0.63723	validation_1-logloss:0.63415
# [30]	validation_0-logloss:0.63674	validation_1-logloss:0.63370
# [31]	validation_0-logloss:0.63614	validation_1-logloss:0.63309
# [32]	validation_0-logloss:0.63556	validation_1-logloss:0.63273
# [33]	validation_0-logloss:0.63492	validation_1-logloss:0.63214
# [34]	validation_0-logloss:0.63427	validation_1-logloss:0.63152
# [35]	validation_0-logloss:0.63383	validation_1-logloss:0.63126
# [36]	validation_0-logloss:0.63253	validation_1-logloss:0.63015
# [37]	validation_0-logloss:0.63117	validation_1-logloss:0.62894
# [38]	validation_0-logloss:0.63058	validation_1-logloss:0.62832
# [39]	validation_0-logloss:0.63002	validation_1-logloss:0.62777
# [40]	validation_0-logloss:0.62939	validation_1-logloss:0.62700
# [41]	validation_0-logloss:0.62898	validation_1-logloss:0.62681
# [42]	validation_0-logloss:0.62863	validation_1-logloss:0.62668
# [43]	validation_0-logloss:0.62826	validation_1-logloss:0.62638
# [44]	validation_0-logloss:0.62789	validation_1-logloss:0.62613
# [45]	validation_0-logloss:0.62698	validation_1-logloss:0.62531
# [46]	validation_0-logloss:0.62645	validation_1-logloss:0.62472
# [47]	validation_0-logloss:0.62611	validation_1-logloss:0.62430
# [48]	validation_0-logloss:0.62518	validation_1-logloss:0.62369
# [49]	validation_0-logloss:0.62474	validation_1-logloss:0.62340
# [50]	validation_0-logloss:0.62433	validation_1-logloss:0.62333
# [51]	validation_0-logloss:0.62403	validation_1-logloss:0.62323
# [52]	validation_0-logloss:0.62378	validation_1-logloss:0.62295
# [53]	validation_0-logloss:0.62293	validation_1-logloss:0.62240
# [54]	validation_0-logloss:0.62261	validation_1-logloss:0.62227
# [55]	validation_0-logloss:0.62210	validation_1-logloss:0.62174
# [56]	validation_0-logloss:0.62167	validation_1-logloss:0.62138
# [57]	validation_0-logloss:0.62089	validation_1-logloss:0.62078
# [58]	validation_0-logloss:0.62020	validation_1-logloss:0.62021
# [59]	validation_0-logloss:0.61994	validation_1-logloss:0.62022
# [60]	validation_0-logloss:0.61964	validation_1-logloss:0.62003
# [61]	validation_0-logloss:0.61929	validation_1-logloss:0.61967
# [62]	validation_0-logloss:0.61894	validation_1-logloss:0.61934
# [63]	validation_0-logloss:0.61834	validation_1-logloss:0.61887
# [64]	validation_0-logloss:0.61802	validation_1-logloss:0.61861
# [65]	validation_0-logloss:0.61783	validation_1-logloss:0.61852
# [66]	validation_0-logloss:0.61729	validation_1-logloss:0.61819
# [67]	validation_0-logloss:0.61659	validation_1-logloss:0.61777
# [68]	validation_0-logloss:0.61608	validation_1-logloss:0.61748
# [69]	validation_0-logloss:0.61562	validation_1-logloss:0.61718
# [70]	validation_0-logloss:0.61534	validation_1-logloss:0.61700
# [71]	validation_0-logloss:0.61516	validation_1-logloss:0.61691
# [72]	validation_0-logloss:0.61494	validation_1-logloss:0.61676
# [73]	validation_0-logloss:0.61466	validation_1-logloss:0.61646
# [74]	validation_0-logloss:0.61427	validation_1-logloss:0.61614
# [75]	validation_0-logloss:0.61377	validation_1-logloss:0.61583
# [76]	validation_0-logloss:0.61368	validation_1-logloss:0.61591
# [77]	validation_0-logloss:0.61349	validation_1-logloss:0.61569
# [78]	validation_0-logloss:0.61331	validation_1-logloss:0.61568
# [79]	validation_0-logloss:0.61304	validation_1-logloss:0.61546
# [80]	validation_0-logloss:0.61294	validation_1-logloss:0.61536
# [81]	validation_0-logloss:0.61253	validation_1-logloss:0.61499
# [82]	validation_0-logloss:0.61235	validation_1-logloss:0.61484
# [83]	validation_0-logloss:0.61211	validation_1-logloss:0.61465
# [84]	validation_0-logloss:0.61197	validation_1-logloss:0.61458
# [85]	validation_0-logloss:0.61176	validation_1-logloss:0.61440
# [86]	validation_0-logloss:0.61157	validation_1-logloss:0.61436
# [87]	validation_0-logloss:0.61139	validation_1-logloss:0.61433
# [88]	validation_0-logloss:0.61108	validation_1-logloss:0.61415
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [89]	validation_0-logloss:0.61071	validation_1-logloss:0.61399
# [90]	validation_0-logloss:0.61059	validation_1-logloss:0.61393
# [91]	validation_0-logloss:0.61050	validation_1-logloss:0.61406
# [92]	validation_0-logloss:0.61037	validation_1-logloss:0.61397
# [93]	validation_0-logloss:0.61028	validation_1-logloss:0.61399
# [94]	validation_0-logloss:0.61012	validation_1-logloss:0.61383
# [95]	validation_0-logloss:0.61000	validation_1-logloss:0.61368
# [96]	validation_0-logloss:0.60985	validation_1-logloss:0.61359
# [97]	validation_0-logloss:0.60976	validation_1-logloss:0.61355
# [98]	validation_0-logloss:0.60947	validation_1-logloss:0.61346
# [99]	validation_0-logloss:0.60940	validation_1-logloss:0.61335
# [100]	validation_0-logloss:0.60917	validation_1-logloss:0.61312
# [101]	validation_0-logloss:0.60890	validation_1-logloss:0.61305
# [102]	validation_0-logloss:0.60874	validation_1-logloss:0.61300
# [103]	validation_0-logloss:0.60853	validation_1-logloss:0.61293
# [104]	validation_0-logloss:0.60847	validation_1-logloss:0.61293
# [105]	validation_0-logloss:0.60832	validation_1-logloss:0.61282
# [106]	validation_0-logloss:0.60820	validation_1-logloss:0.61266
# [107]	validation_0-logloss:0.60816	validation_1-logloss:0.61266
# [108]	validation_0-logloss:0.60806	validation_1-logloss:0.61275
# [109]	validation_0-logloss:0.60793	validation_1-logloss:0.61260
# [110]	validation_0-logloss:0.60784	validation_1-logloss:0.61261
# [111]	validation_0-logloss:0.60780	validation_1-logloss:0.61249
# [112]	validation_0-logloss:0.60782	validation_1-logloss:0.61252
# [113]	validation_0-logloss:0.60769	validation_1-logloss:0.61265
# [114]	validation_0-logloss:0.60747	validation_1-logloss:0.61250
# [115]	validation_0-logloss:0.60739	validation_1-logloss:0.61253
# [116]	validation_0-logloss:0.60723	validation_1-logloss:0.61234
# [117]	validation_0-logloss:0.60718	validation_1-logloss:0.61222
# [118]	validation_0-logloss:0.60706	validation_1-logloss:0.61214
# [119]	validation_0-logloss:0.60699	validation_1-logloss:0.61213
# [120]	validation_0-logloss:0.60685	validation_1-logloss:0.61212
# [121]	validation_0-logloss:0.60672	validation_1-logloss:0.61209
# [122]	validation_0-logloss:0.60667	validation_1-logloss:0.61206
# [123]	validation_0-logloss:0.60637	validation_1-logloss:0.61189
# [124]	validation_0-logloss:0.60630	validation_1-logloss:0.61190
# [125]	validation_0-logloss:0.60613	validation_1-logloss:0.61176
# [126]	validation_0-logloss:0.60607	validation_1-logloss:0.61172
# [127]	validation_0-logloss:0.60600	validation_1-logloss:0.61168
# [128]	validation_0-logloss:0.60589	validation_1-logloss:0.61169
# [129]	validation_0-logloss:0.60565	validation_1-logloss:0.61160
# [130]	validation_0-logloss:0.60561	validation_1-logloss:0.61161
# [131]	validation_0-logloss:0.60547	validation_1-logloss:0.61149
# [132]	validation_0-logloss:0.60534	validation_1-logloss:0.61151
# [133]	validation_0-logloss:0.60515	validation_1-logloss:0.61142
# [134]	validation_0-logloss:0.60499	validation_1-logloss:0.61131
# [135]	validation_0-logloss:0.60487	validation_1-logloss:0.61130
# [136]	validation_0-logloss:0.60463	validation_1-logloss:0.61112
# [137]	validation_0-logloss:0.60459	validation_1-logloss:0.61110
# [138]	validation_0-logloss:0.60468	validation_1-logloss:0.61121
# [139]	validation_0-logloss:0.60458	validation_1-logloss:0.61126
# [140]	validation_0-logloss:0.60445	validation_1-logloss:0.61120
# [141]	validation_0-logloss:0.60443	validation_1-logloss:0.61141
# [142]	validation_0-logloss:0.60434	validation_1-logloss:0.61137
# [143]	validation_0-logloss:0.60413	validation_1-logloss:0.61129
# [144]	validation_0-logloss:0.60400	validation_1-logloss:0.61119
# [145]	validation_0-logloss:0.60406	validation_1-logloss:0.61126
# [146]	validation_0-logloss:0.60390	validation_1-logloss:0.61109
# [147]	validation_0-logloss:0.60369	validation_1-logloss:0.61115
# [148]	validation_0-logloss:0.60360	validation_1-logloss:0.61119
# [149]	validation_0-logloss:0.60341	validation_1-logloss:0.61124
# [150]	validation_0-logloss:0.60335	validation_1-logloss:0.61124
# [151]	validation_0-logloss:0.60328	validation_1-logloss:0.61129
# [152]	validation_0-logloss:0.60315	validation_1-logloss:0.61133
# [153]	validation_0-logloss:0.60308	validation_1-logloss:0.61129
# [154]	validation_0-logloss:0.60291	validation_1-logloss:0.61115
# [155]	validation_0-logloss:0.60283	validation_1-logloss:0.61112
# [156]	validation_0-logloss:0.60275	validation_1-logloss:0.61102
# [157]	validation_0-logloss:0.60267	validation_1-logloss:0.61109
# [158]	validation_0-logloss:0.60265	validation_1-logloss:0.61118
# [159]	validation_0-logloss:0.60259	validation_1-logloss:0.61121
# [160]	validation_0-logloss:0.60250	validation_1-logloss:0.61120
# [161]	validation_0-logloss:0.60246	validation_1-logloss:0.61119
# [162]	validation_0-logloss:0.60231	validation_1-logloss:0.61113
# [163]	validation_0-logloss:0.60222	validation_1-logloss:0.61110
# [164]	validation_0-logloss:0.60215	validation_1-logloss:0.61117
# [165]	validation_0-logloss:0.60204	validation_1-logloss:0.61121
# [166]	validation_0-logloss:0.60202	validation_1-logloss:0.61120
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.3s
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.2min
# [0]	validation_0-logloss:0.67179	validation_1-logloss:0.66485
# [1]	validation_0-logloss:0.66992	validation_1-logloss:0.66313
# [2]	validation_0-logloss:0.66876	validation_1-logloss:0.66199
# [3]	validation_0-logloss:0.66747	validation_1-logloss:0.66093
# [4]	validation_0-logloss:0.66580	validation_1-logloss:0.65943
# [5]	validation_0-logloss:0.66282	validation_1-logloss:0.65664
# [6]	validation_0-logloss:0.66169	validation_1-logloss:0.65552
# [7]	validation_0-logloss:0.66054	validation_1-logloss:0.65508
# [8]	validation_0-logloss:0.65907	validation_1-logloss:0.65399
# [9]	validation_0-logloss:0.65792	validation_1-logloss:0.65306
# [10]	validation_0-logloss:0.65613	validation_1-logloss:0.65158
# [11]	validation_0-logloss:0.65514	validation_1-logloss:0.65062
# [12]	validation_0-logloss:0.65442	validation_1-logloss:0.64982
# [13]	validation_0-logloss:0.65347	validation_1-logloss:0.64905
# [14]	validation_0-logloss:0.65249	validation_1-logloss:0.64801
# [15]	validation_0-logloss:0.65114	validation_1-logloss:0.64671
# [16]	validation_0-logloss:0.65053	validation_1-logloss:0.64610
# [17]	validation_0-logloss:0.64963	validation_1-logloss:0.64513
# [18]	validation_0-logloss:0.64883	validation_1-logloss:0.64443
# [19]	validation_0-logloss:0.64804	validation_1-logloss:0.64343
# [20]	validation_0-logloss:0.64563	validation_1-logloss:0.64109
# [21]	validation_0-logloss:0.64482	validation_1-logloss:0.64029
# [22]	validation_0-logloss:0.64325	validation_1-logloss:0.63887
# [23]	validation_0-logloss:0.64221	validation_1-logloss:0.63791
# [24]	validation_0-logloss:0.64148	validation_1-logloss:0.63720
# [25]	validation_0-logloss:0.64058	validation_1-logloss:0.63647
# [26]	validation_0-logloss:0.64006	validation_1-logloss:0.63595
# [27]	validation_0-logloss:0.63909	validation_1-logloss:0.63500
# [28]	validation_0-logloss:0.63847	validation_1-logloss:0.63454
# [29]	validation_0-logloss:0.63763	validation_1-logloss:0.63357
# [30]	validation_0-logloss:0.63713	validation_1-logloss:0.63317
# [31]	validation_0-logloss:0.63647	validation_1-logloss:0.63258
# [32]	validation_0-logloss:0.63599	validation_1-logloss:0.63210
# [33]	validation_0-logloss:0.63520	validation_1-logloss:0.63150
# [34]	validation_0-logloss:0.63456	validation_1-logloss:0.63078
# [35]	validation_0-logloss:0.63410	validation_1-logloss:0.63047
# [36]	validation_0-logloss:0.63274	validation_1-logloss:0.62944
# [37]	validation_0-logloss:0.63136	validation_1-logloss:0.62820
# [38]	validation_0-logloss:0.63071	validation_1-logloss:0.62745
# [39]	validation_0-logloss:0.63011	validation_1-logloss:0.62679
# [40]	validation_0-logloss:0.62943	validation_1-logloss:0.62609
# [41]	validation_0-logloss:0.62903	validation_1-logloss:0.62609
# [42]	validation_0-logloss:0.62864	validation_1-logloss:0.62592
# [43]	validation_0-logloss:0.62822	validation_1-logloss:0.62551
# [44]	validation_0-logloss:0.62792	validation_1-logloss:0.62543
# [45]	validation_0-logloss:0.62699	validation_1-logloss:0.62465
# [46]	validation_0-logloss:0.62645	validation_1-logloss:0.62398
# [47]	validation_0-logloss:0.62612	validation_1-logloss:0.62365
# [48]	validation_0-logloss:0.62517	validation_1-logloss:0.62286
# [49]	validation_0-logloss:0.62472	validation_1-logloss:0.62252
# [50]	validation_0-logloss:0.62446	validation_1-logloss:0.62241
# [51]	validation_0-logloss:0.62425	validation_1-logloss:0.62219
# [52]	validation_0-logloss:0.62401	validation_1-logloss:0.62196
# [53]	validation_0-logloss:0.62322	validation_1-logloss:0.62135
# [54]	validation_0-logloss:0.62290	validation_1-logloss:0.62117
# [55]	validation_0-logloss:0.62234	validation_1-logloss:0.62069
# [56]	validation_0-logloss:0.62212	validation_1-logloss:0.62042
# [57]	validation_0-logloss:0.62134	validation_1-logloss:0.61981
# [58]	validation_0-logloss:0.62074	validation_1-logloss:0.61939
# [59]	validation_0-logloss:0.62051	validation_1-logloss:0.61935
# [60]	validation_0-logloss:0.62032	validation_1-logloss:0.61922
# [61]	validation_0-logloss:0.61988	validation_1-logloss:0.61883
# [62]	validation_0-logloss:0.61966	validation_1-logloss:0.61845
# [63]	validation_0-logloss:0.61903	validation_1-logloss:0.61797
# [64]	validation_0-logloss:0.61861	validation_1-logloss:0.61763
# [65]	validation_0-logloss:0.61837	validation_1-logloss:0.61747
# [66]	validation_0-logloss:0.61781	validation_1-logloss:0.61724
# [67]	validation_0-logloss:0.61711	validation_1-logloss:0.61676
# [68]	validation_0-logloss:0.61659	validation_1-logloss:0.61635
# [69]	validation_0-logloss:0.61616	validation_1-logloss:0.61605
# [70]	validation_0-logloss:0.61590	validation_1-logloss:0.61586
# [71]	validation_0-logloss:0.61573	validation_1-logloss:0.61585
# [72]	validation_0-logloss:0.61546	validation_1-logloss:0.61560
# [73]	validation_0-logloss:0.61530	validation_1-logloss:0.61545
# [74]	validation_0-logloss:0.61489	validation_1-logloss:0.61514
# [75]	validation_0-logloss:0.61428	validation_1-logloss:0.61462
# [76]	validation_0-logloss:0.61415	validation_1-logloss:0.61461
# [77]	validation_0-logloss:0.61404	validation_1-logloss:0.61439
# [78]	validation_0-logloss:0.61385	validation_1-logloss:0.61436
# [79]	validation_0-logloss:0.61354	validation_1-logloss:0.61407
# [80]	validation_0-logloss:0.61339	validation_1-logloss:0.61394
# [81]	validation_0-logloss:0.61297	validation_1-logloss:0.61364
# [82]	validation_0-logloss:0.61275	validation_1-logloss:0.61359
# [83]	validation_0-logloss:0.61254	validation_1-logloss:0.61333
# [84]	validation_0-logloss:0.61228	validation_1-logloss:0.61310
# [85]	validation_0-logloss:0.61201	validation_1-logloss:0.61275
# [86]	validation_0-logloss:0.61183	validation_1-logloss:0.61265
# [87]	validation_0-logloss:0.61170	validation_1-logloss:0.61257
# [88]	validation_0-logloss:0.61134	validation_1-logloss:0.61241
# [89]	validation_0-logloss:0.61099	validation_1-logloss:0.61222
# [90]	validation_0-logloss:0.61074	validation_1-logloss:0.61199
# [91]	validation_0-logloss:0.61067	validation_1-logloss:0.61198
# [92]	validation_0-logloss:0.61063	validation_1-logloss:0.61202
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [93]	validation_0-logloss:0.61058	validation_1-logloss:0.61191
# [94]	validation_0-logloss:0.61053	validation_1-logloss:0.61181
# [95]	validation_0-logloss:0.61045	validation_1-logloss:0.61163
# [96]	validation_0-logloss:0.61023	validation_1-logloss:0.61145
# [97]	validation_0-logloss:0.61004	validation_1-logloss:0.61126
# [98]	validation_0-logloss:0.60976	validation_1-logloss:0.61118
# [99]	validation_0-logloss:0.60955	validation_1-logloss:0.61086
# [100]	validation_0-logloss:0.60932	validation_1-logloss:0.61055
# [101]	validation_0-logloss:0.60905	validation_1-logloss:0.61051
# [102]	validation_0-logloss:0.60902	validation_1-logloss:0.61041
# [103]	validation_0-logloss:0.60877	validation_1-logloss:0.61044
# [104]	validation_0-logloss:0.60863	validation_1-logloss:0.61027
# [105]	validation_0-logloss:0.60840	validation_1-logloss:0.61012
# [106]	validation_0-logloss:0.60842	validation_1-logloss:0.61017
# [107]	validation_0-logloss:0.60822	validation_1-logloss:0.61000
# [108]	validation_0-logloss:0.60808	validation_1-logloss:0.61001
# [109]	validation_0-logloss:0.60783	validation_1-logloss:0.60973
# [110]	validation_0-logloss:0.60778	validation_1-logloss:0.60973
# [111]	validation_0-logloss:0.60776	validation_1-logloss:0.60978
# [112]	validation_0-logloss:0.60767	validation_1-logloss:0.60981
# [113]	validation_0-logloss:0.60761	validation_1-logloss:0.60971
# [114]	validation_0-logloss:0.60746	validation_1-logloss:0.60938
# [115]	validation_0-logloss:0.60734	validation_1-logloss:0.60938
# [116]	validation_0-logloss:0.60725	validation_1-logloss:0.60917
# [117]	validation_0-logloss:0.60722	validation_1-logloss:0.60927
# [118]	validation_0-logloss:0.60720	validation_1-logloss:0.60921
# [119]	validation_0-logloss:0.60725	validation_1-logloss:0.60931
# [120]	validation_0-logloss:0.60718	validation_1-logloss:0.60925
# [121]	validation_0-logloss:0.60706	validation_1-logloss:0.60915
# [122]	validation_0-logloss:0.60697	validation_1-logloss:0.60906
# [123]	validation_0-logloss:0.60670	validation_1-logloss:0.60899
# [124]	validation_0-logloss:0.60665	validation_1-logloss:0.60894
# [125]	validation_0-logloss:0.60650	validation_1-logloss:0.60886
# [126]	validation_0-logloss:0.60648	validation_1-logloss:0.60881
# [127]	validation_0-logloss:0.60643	validation_1-logloss:0.60897
# [128]	validation_0-logloss:0.60642	validation_1-logloss:0.60892
# [129]	validation_0-logloss:0.60622	validation_1-logloss:0.60898
# [130]	validation_0-logloss:0.60621	validation_1-logloss:0.60893
# [131]	validation_0-logloss:0.60603	validation_1-logloss:0.60874
# [132]	validation_0-logloss:0.60593	validation_1-logloss:0.60873
# [133]	validation_0-logloss:0.60573	validation_1-logloss:0.60860
# [134]	validation_0-logloss:0.60564	validation_1-logloss:0.60865
# [135]	validation_0-logloss:0.60560	validation_1-logloss:0.60883
# [136]	validation_0-logloss:0.60537	validation_1-logloss:0.60866
# [137]	validation_0-logloss:0.60539	validation_1-logloss:0.60865
# [138]	validation_0-logloss:0.60539	validation_1-logloss:0.60864
# [139]	validation_0-logloss:0.60539	validation_1-logloss:0.60858
# [140]	validation_0-logloss:0.60536	validation_1-logloss:0.60870
# [141]	validation_0-logloss:0.60533	validation_1-logloss:0.60874
# [142]	validation_0-logloss:0.60518	validation_1-logloss:0.60883
# [143]	validation_0-logloss:0.60498	validation_1-logloss:0.60877
# [144]	validation_0-logloss:0.60486	validation_1-logloss:0.60868
# [145]	validation_0-logloss:0.60479	validation_1-logloss:0.60866
# [146]	validation_0-logloss:0.60473	validation_1-logloss:0.60852
# [147]	validation_0-logloss:0.60468	validation_1-logloss:0.60860
# [148]	validation_0-logloss:0.60455	validation_1-logloss:0.60862
# [149]	validation_0-logloss:0.60438	validation_1-logloss:0.60866
# [150]	validation_0-logloss:0.60423	validation_1-logloss:0.60866
# [151]	validation_0-logloss:0.60406	validation_1-logloss:0.60851
# [152]	validation_0-logloss:0.60397	validation_1-logloss:0.60852
# [153]	validation_0-logloss:0.60386	validation_1-logloss:0.60831
# [154]	validation_0-logloss:0.60370	validation_1-logloss:0.60820
# [155]	validation_0-logloss:0.60362	validation_1-logloss:0.60808
# [156]	validation_0-logloss:0.60356	validation_1-logloss:0.60812
# [157]	validation_0-logloss:0.60352	validation_1-logloss:0.60811
# [158]	validation_0-logloss:0.60336	validation_1-logloss:0.60825
# [159]	validation_0-logloss:0.60326	validation_1-logloss:0.60817
# [160]	validation_0-logloss:0.60314	validation_1-logloss:0.60813
# [161]	validation_0-logloss:0.60317	validation_1-logloss:0.60815
# [162]	validation_0-logloss:0.60314	validation_1-logloss:0.60826
# [163]	validation_0-logloss:0.60303	validation_1-logloss:0.60845
# [164]	validation_0-logloss:0.60297	validation_1-logloss:0.60856
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.3s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.2min
# [0]	validation_0-logloss:0.67180	validation_1-logloss:0.66510
# [1]	validation_0-logloss:0.66993	validation_1-logloss:0.66333
# [2]	validation_0-logloss:0.66889	validation_1-logloss:0.66194
# [3]	validation_0-logloss:0.66762	validation_1-logloss:0.66099
# [4]	validation_0-logloss:0.66597	validation_1-logloss:0.65974
# [5]	validation_0-logloss:0.66296	validation_1-logloss:0.65678
# [6]	validation_0-logloss:0.66198	validation_1-logloss:0.65572
# [7]	validation_0-logloss:0.66074	validation_1-logloss:0.65510
# [8]	validation_0-logloss:0.65929	validation_1-logloss:0.65385
# [9]	validation_0-logloss:0.65801	validation_1-logloss:0.65287
# [10]	validation_0-logloss:0.65605	validation_1-logloss:0.65118
# [11]	validation_0-logloss:0.65491	validation_1-logloss:0.65008
# [12]	validation_0-logloss:0.65429	validation_1-logloss:0.64907
# [13]	validation_0-logloss:0.65335	validation_1-logloss:0.64817
# [14]	validation_0-logloss:0.65236	validation_1-logloss:0.64724
# [15]	validation_0-logloss:0.65080	validation_1-logloss:0.64582
# [16]	validation_0-logloss:0.65018	validation_1-logloss:0.64533
# [17]	validation_0-logloss:0.64920	validation_1-logloss:0.64409
# [18]	validation_0-logloss:0.64844	validation_1-logloss:0.64340
# [19]	validation_0-logloss:0.64808	validation_1-logloss:0.64295
# [20]	validation_0-logloss:0.64561	validation_1-logloss:0.64062
# [21]	validation_0-logloss:0.64477	validation_1-logloss:0.63988
# [22]	validation_0-logloss:0.64317	validation_1-logloss:0.63812
# [23]	validation_0-logloss:0.64199	validation_1-logloss:0.63700
# [24]	validation_0-logloss:0.64120	validation_1-logloss:0.63610
# [25]	validation_0-logloss:0.64027	validation_1-logloss:0.63535
# [26]	validation_0-logloss:0.63986	validation_1-logloss:0.63507
# [27]	validation_0-logloss:0.63891	validation_1-logloss:0.63431
# [28]	validation_0-logloss:0.63842	validation_1-logloss:0.63390
# [29]	validation_0-logloss:0.63749	validation_1-logloss:0.63281
# [30]	validation_0-logloss:0.63696	validation_1-logloss:0.63232
# [31]	validation_0-logloss:0.63643	validation_1-logloss:0.63199
# [32]	validation_0-logloss:0.63592	validation_1-logloss:0.63165
# [33]	validation_0-logloss:0.63509	validation_1-logloss:0.63095
# [34]	validation_0-logloss:0.63436	validation_1-logloss:0.63032
# [35]	validation_0-logloss:0.63397	validation_1-logloss:0.63008
# [36]	validation_0-logloss:0.63274	validation_1-logloss:0.62912
# [37]	validation_0-logloss:0.63141	validation_1-logloss:0.62803
# [38]	validation_0-logloss:0.63075	validation_1-logloss:0.62746
# [39]	validation_0-logloss:0.63017	validation_1-logloss:0.62676
# [40]	validation_0-logloss:0.62947	validation_1-logloss:0.62602
# [41]	validation_0-logloss:0.62921	validation_1-logloss:0.62576
# [42]	validation_0-logloss:0.62885	validation_1-logloss:0.62542
# [43]	validation_0-logloss:0.62845	validation_1-logloss:0.62521
# [44]	validation_0-logloss:0.62826	validation_1-logloss:0.62479
# [45]	validation_0-logloss:0.62729	validation_1-logloss:0.62388
# [46]	validation_0-logloss:0.62695	validation_1-logloss:0.62330
# [47]	validation_0-logloss:0.62673	validation_1-logloss:0.62333
# [48]	validation_0-logloss:0.62579	validation_1-logloss:0.62248
# [49]	validation_0-logloss:0.62542	validation_1-logloss:0.62213
# [50]	validation_0-logloss:0.62504	validation_1-logloss:0.62203
# [51]	validation_0-logloss:0.62484	validation_1-logloss:0.62174
# [52]	validation_0-logloss:0.62459	validation_1-logloss:0.62154
# [53]	validation_0-logloss:0.62371	validation_1-logloss:0.62098
# [54]	validation_0-logloss:0.62335	validation_1-logloss:0.62092
# [55]	validation_0-logloss:0.62276	validation_1-logloss:0.62045
# [56]	validation_0-logloss:0.62240	validation_1-logloss:0.62021
# [57]	validation_0-logloss:0.62167	validation_1-logloss:0.61960
# [58]	validation_0-logloss:0.62097	validation_1-logloss:0.61910
# [59]	validation_0-logloss:0.62087	validation_1-logloss:0.61911
# [60]	validation_0-logloss:0.62061	validation_1-logloss:0.61885
# [61]	validation_0-logloss:0.62016	validation_1-logloss:0.61850
# [62]	validation_0-logloss:0.62023	validation_1-logloss:0.61848
# [63]	validation_0-logloss:0.61961	validation_1-logloss:0.61803
# [64]	validation_0-logloss:0.61916	validation_1-logloss:0.61763
# [65]	validation_0-logloss:0.61905	validation_1-logloss:0.61760
# [66]	validation_0-logloss:0.61850	validation_1-logloss:0.61730
# [67]	validation_0-logloss:0.61795	validation_1-logloss:0.61676
# [68]	validation_0-logloss:0.61761	validation_1-logloss:0.61643
# [69]	validation_0-logloss:0.61717	validation_1-logloss:0.61618
# [70]	validation_0-logloss:0.61688	validation_1-logloss:0.61603
# [71]	validation_0-logloss:0.61665	validation_1-logloss:0.61586
# [72]	validation_0-logloss:0.61666	validation_1-logloss:0.61568
# [73]	validation_0-logloss:0.61662	validation_1-logloss:0.61574
# [74]	validation_0-logloss:0.61619	validation_1-logloss:0.61541
# [75]	validation_0-logloss:0.61562	validation_1-logloss:0.61495
# [76]	validation_0-logloss:0.61551	validation_1-logloss:0.61491
# [77]	validation_0-logloss:0.61539	validation_1-logloss:0.61448
# [78]	validation_0-logloss:0.61521	validation_1-logloss:0.61450
# [79]	validation_0-logloss:0.61494	validation_1-logloss:0.61428
# [80]	validation_0-logloss:0.61476	validation_1-logloss:0.61426
# [81]	validation_0-logloss:0.61436	validation_1-logloss:0.61402
# [82]	validation_0-logloss:0.61421	validation_1-logloss:0.61397
# [83]	validation_0-logloss:0.61412	validation_1-logloss:0.61387
# [84]	validation_0-logloss:0.61379	validation_1-logloss:0.61364
# [85]	validation_0-logloss:0.61353	validation_1-logloss:0.61351
# [86]	validation_0-logloss:0.61342	validation_1-logloss:0.61338
# [87]	validation_0-logloss:0.61320	validation_1-logloss:0.61330
# [88]	validation_0-logloss:0.61289	validation_1-logloss:0.61313
# [89]	validation_0-logloss:0.61256	validation_1-logloss:0.61298
# [90]	validation_0-logloss:0.61230	validation_1-logloss:0.61275
# [91]	validation_0-logloss:0.61215	validation_1-logloss:0.61266
# [92]	validation_0-logloss:0.61205	validation_1-logloss:0.61257
# [93]	validation_0-logloss:0.61187	validation_1-logloss:0.61248
# [94]	validation_0-logloss:0.61178	validation_1-logloss:0.61236
# [95]	validation_0-logloss:0.61165	validation_1-logloss:0.61214
# [96]	validation_0-logloss:0.61174	validation_1-logloss:0.61222
# [97]	validation_0-logloss:0.61162	validation_1-logloss:0.61209
# [98]	validation_0-logloss:0.61132	validation_1-logloss:0.61204
# [99]	validation_0-logloss:0.61105	validation_1-logloss:0.61173
# [100]	validation_0-logloss:0.61080	validation_1-logloss:0.61148
# [101]	validation_0-logloss:0.61053	validation_1-logloss:0.61152
# [102]	validation_0-logloss:0.61042	validation_1-logloss:0.61135
# [103]	validation_0-logloss:0.61017	validation_1-logloss:0.61129
# [104]	validation_0-logloss:0.61027	validation_1-logloss:0.61117
# [105]	validation_0-logloss:0.61002	validation_1-logloss:0.61099
# [106]	validation_0-logloss:0.61003	validation_1-logloss:0.61084
# [107]	validation_0-logloss:0.60980	validation_1-logloss:0.61064
# [108]	validation_0-logloss:0.60968	validation_1-logloss:0.61064
# [109]	validation_0-logloss:0.60950	validation_1-logloss:0.61044
# [110]	validation_0-logloss:0.60965	validation_1-logloss:0.61057
# [111]	validation_0-logloss:0.60955	validation_1-logloss:0.61056
# [112]	validation_0-logloss:0.60944	validation_1-logloss:0.61053
# [113]	validation_0-logloss:0.60937	validation_1-logloss:0.61056
# [114]	validation_0-logloss:0.60914	validation_1-logloss:0.61030
# [115]	validation_0-logloss:0.60910	validation_1-logloss:0.61032
# [116]	validation_0-logloss:0.60889	validation_1-logloss:0.61010
# [117]	validation_0-logloss:0.60882	validation_1-logloss:0.61017
# [118]	validation_0-logloss:0.60872	validation_1-logloss:0.61005
# [119]	validation_0-logloss:0.60868	validation_1-logloss:0.61003
# [120]	validation_0-logloss:0.60867	validation_1-logloss:0.61016
# [121]	validation_0-logloss:0.60848	validation_1-logloss:0.61002
# [122]	validation_0-logloss:0.60862	validation_1-logloss:0.61012
# [123]	validation_0-logloss:0.60836	validation_1-logloss:0.61010
# [124]	validation_0-logloss:0.60844	validation_1-logloss:0.61005
# [125]	validation_0-logloss:0.60830	validation_1-logloss:0.60996
# [126]	validation_0-logloss:0.60832	validation_1-logloss:0.61007
# [127]	validation_0-logloss:0.60824	validation_1-logloss:0.61004
# [128]	validation_0-logloss:0.60820	validation_1-logloss:0.60996
# [129]	validation_0-logloss:0.60800	validation_1-logloss:0.60989
# [130]	validation_0-logloss:0.60797	validation_1-logloss:0.60984
# [131]	validation_0-logloss:0.60784	validation_1-logloss:0.60975
# [132]	validation_0-logloss:0.60779	validation_1-logloss:0.60980
# [133]	validation_0-logloss:0.60754	validation_1-logloss:0.60965
# [134]	validation_0-logloss:0.60735	validation_1-logloss:0.60956
# [135]	validation_0-logloss:0.60732	validation_1-logloss:0.60972
# [136]	validation_0-logloss:0.60706	validation_1-logloss:0.60951
# [137]	validation_0-logloss:0.60703	validation_1-logloss:0.60942
# [138]	validation_0-logloss:0.60694	validation_1-logloss:0.60945
# [139]	validation_0-logloss:0.60693	validation_1-logloss:0.60948
# [140]	validation_0-logloss:0.60677	validation_1-logloss:0.60942
# [141]	validation_0-logloss:0.60689	validation_1-logloss:0.60953
# [142]	validation_0-logloss:0.60677	validation_1-logloss:0.60936
# [143]	validation_0-logloss:0.60662	validation_1-logloss:0.60935
# [144]	validation_0-logloss:0.60655	validation_1-logloss:0.60937
# [145]	validation_0-logloss:0.60651	validation_1-logloss:0.60940
# [146]	validation_0-logloss:0.60636	validation_1-logloss:0.60921
# [147]	validation_0-logloss:0.60644	validation_1-logloss:0.60925
# [148]	validation_0-logloss:0.60639	validation_1-logloss:0.60928
# [149]	validation_0-logloss:0.60621	validation_1-logloss:0.60933
# [150]	validation_0-logloss:0.60622	validation_1-logloss:0.60929
# [151]	validation_0-logloss:0.60601	validation_1-logloss:0.60912
# [152]	validation_0-logloss:0.60595	validation_1-logloss:0.60913
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [153]	validation_0-logloss:0.60585	validation_1-logloss:0.60904
# [154]	validation_0-logloss:0.60573	validation_1-logloss:0.60898
# [155]	validation_0-logloss:0.60557	validation_1-logloss:0.60893
# [156]	validation_0-logloss:0.60548	validation_1-logloss:0.60892
# [157]	validation_0-logloss:0.60546	validation_1-logloss:0.60886
# [158]	validation_0-logloss:0.60543	validation_1-logloss:0.60891
# [159]	validation_0-logloss:0.60534	validation_1-logloss:0.60881
# [160]	validation_0-logloss:0.60519	validation_1-logloss:0.60869
# [161]	validation_0-logloss:0.60508	validation_1-logloss:0.60853
# [162]	validation_0-logloss:0.60506	validation_1-logloss:0.60856
# [163]	validation_0-logloss:0.60500	validation_1-logloss:0.60852
# [164]	validation_0-logloss:0.60498	validation_1-logloss:0.60850
# [165]	validation_0-logloss:0.60494	validation_1-logloss:0.60852
# [166]	validation_0-logloss:0.60489	validation_1-logloss:0.60852
# [167]	validation_0-logloss:0.60477	validation_1-logloss:0.60844
# [168]	validation_0-logloss:0.60478	validation_1-logloss:0.60845
# [169]	validation_0-logloss:0.60469	validation_1-logloss:0.60845
# [170]	validation_0-logloss:0.60457	validation_1-logloss:0.60845
# [171]	validation_0-logloss:0.60446	validation_1-logloss:0.60844
# [172]	validation_0-logloss:0.60439	validation_1-logloss:0.60838
# [173]	validation_0-logloss:0.60436	validation_1-logloss:0.60839
# [174]	validation_0-logloss:0.60421	validation_1-logloss:0.60828
# [175]	validation_0-logloss:0.60412	validation_1-logloss:0.60816
# [176]	validation_0-logloss:0.60400	validation_1-logloss:0.60815
# [177]	validation_0-logloss:0.60394	validation_1-logloss:0.60820
# [178]	validation_0-logloss:0.60387	validation_1-logloss:0.60816
# [179]	validation_0-logloss:0.60382	validation_1-logloss:0.60810
# [180]	validation_0-logloss:0.60380	validation_1-logloss:0.60804
# [181]	validation_0-logloss:0.60372	validation_1-logloss:0.60808
# [182]	validation_0-logloss:0.60372	validation_1-logloss:0.60814
# [183]	validation_0-logloss:0.60368	validation_1-logloss:0.60825
# [184]	validation_0-logloss:0.60360	validation_1-logloss:0.60821
# [185]	validation_0-logloss:0.60353	validation_1-logloss:0.60820
# [186]	validation_0-logloss:0.60342	validation_1-logloss:0.60828
# [187]	validation_0-logloss:0.60341	validation_1-logloss:0.60829
# [188]	validation_0-logloss:0.60340	validation_1-logloss:0.60840
# [189]	validation_0-logloss:0.60340	validation_1-logloss:0.60837
# [190]	validation_0-logloss:0.60340	validation_1-logloss:0.60843
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.2s
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.3min
# [0]	validation_0-logloss:0.67174	validation_1-logloss:0.66499
# [1]	validation_0-logloss:0.67003	validation_1-logloss:0.66345
# [2]	validation_0-logloss:0.66879	validation_1-logloss:0.66250
# [3]	validation_0-logloss:0.66756	validation_1-logloss:0.66154
# [4]	validation_0-logloss:0.66592	validation_1-logloss:0.66034
# [5]	validation_0-logloss:0.66288	validation_1-logloss:0.65748
# [6]	validation_0-logloss:0.66179	validation_1-logloss:0.65651
# [7]	validation_0-logloss:0.66062	validation_1-logloss:0.65599
# [8]	validation_0-logloss:0.65921	validation_1-logloss:0.65494
# [9]	validation_0-logloss:0.65805	validation_1-logloss:0.65385
# [10]	validation_0-logloss:0.65630	validation_1-logloss:0.65231
# [11]	validation_0-logloss:0.65517	validation_1-logloss:0.65130
# [12]	validation_0-logloss:0.65433	validation_1-logloss:0.65051
# [13]	validation_0-logloss:0.65336	validation_1-logloss:0.64980
# [14]	validation_0-logloss:0.65231	validation_1-logloss:0.64883
# [15]	validation_0-logloss:0.65097	validation_1-logloss:0.64766
# [16]	validation_0-logloss:0.65034	validation_1-logloss:0.64711
# [17]	validation_0-logloss:0.64944	validation_1-logloss:0.64606
# [18]	validation_0-logloss:0.64866	validation_1-logloss:0.64557
# [19]	validation_0-logloss:0.64795	validation_1-logloss:0.64496
# [20]	validation_0-logloss:0.64541	validation_1-logloss:0.64258
# [21]	validation_0-logloss:0.64455	validation_1-logloss:0.64181
# [22]	validation_0-logloss:0.64300	validation_1-logloss:0.64033
# [23]	validation_0-logloss:0.64197	validation_1-logloss:0.63946
# [24]	validation_0-logloss:0.64123	validation_1-logloss:0.63869
# [25]	validation_0-logloss:0.64028	validation_1-logloss:0.63785
# [26]	validation_0-logloss:0.63974	validation_1-logloss:0.63742
# [27]	validation_0-logloss:0.63887	validation_1-logloss:0.63647
# [28]	validation_0-logloss:0.63820	validation_1-logloss:0.63600
# [29]	validation_0-logloss:0.63742	validation_1-logloss:0.63521
# [30]	validation_0-logloss:0.63691	validation_1-logloss:0.63485
# [31]	validation_0-logloss:0.63631	validation_1-logloss:0.63424
# [32]	validation_0-logloss:0.63581	validation_1-logloss:0.63409
# [33]	validation_0-logloss:0.63505	validation_1-logloss:0.63356
# [34]	validation_0-logloss:0.63425	validation_1-logloss:0.63291
# [35]	validation_0-logloss:0.63385	validation_1-logloss:0.63270
# [36]	validation_0-logloss:0.63256	validation_1-logloss:0.63158
# [37]	validation_0-logloss:0.63118	validation_1-logloss:0.63046
# [38]	validation_0-logloss:0.63050	validation_1-logloss:0.62982
# [39]	validation_0-logloss:0.62987	validation_1-logloss:0.62913
# [40]	validation_0-logloss:0.62922	validation_1-logloss:0.62838
# [41]	validation_0-logloss:0.62880	validation_1-logloss:0.62816
# [42]	validation_0-logloss:0.62841	validation_1-logloss:0.62796
# [43]	validation_0-logloss:0.62804	validation_1-logloss:0.62770
# [44]	validation_0-logloss:0.62768	validation_1-logloss:0.62760
# [45]	validation_0-logloss:0.62675	validation_1-logloss:0.62683
# [46]	validation_0-logloss:0.62616	validation_1-logloss:0.62600
# [47]	validation_0-logloss:0.62577	validation_1-logloss:0.62558
# [48]	validation_0-logloss:0.62487	validation_1-logloss:0.62483
# [49]	validation_0-logloss:0.62453	validation_1-logloss:0.62448
# [50]	validation_0-logloss:0.62427	validation_1-logloss:0.62438
# [51]	validation_0-logloss:0.62402	validation_1-logloss:0.62414
# [52]	validation_0-logloss:0.62373	validation_1-logloss:0.62393
# [53]	validation_0-logloss:0.62289	validation_1-logloss:0.62317
# [54]	validation_0-logloss:0.62250	validation_1-logloss:0.62307
# [55]	validation_0-logloss:0.62193	validation_1-logloss:0.62253
# [56]	validation_0-logloss:0.62148	validation_1-logloss:0.62216
# [57]	validation_0-logloss:0.62073	validation_1-logloss:0.62163
# [58]	validation_0-logloss:0.62003	validation_1-logloss:0.62114
# [59]	validation_0-logloss:0.61976	validation_1-logloss:0.62103
# [60]	validation_0-logloss:0.61955	validation_1-logloss:0.62086
# [61]	validation_0-logloss:0.61922	validation_1-logloss:0.62048
# [62]	validation_0-logloss:0.61901	validation_1-logloss:0.62035
# [63]	validation_0-logloss:0.61838	validation_1-logloss:0.61998
# [64]	validation_0-logloss:0.61792	validation_1-logloss:0.61957
# [65]	validation_0-logloss:0.61773	validation_1-logloss:0.61956
# [66]	validation_0-logloss:0.61715	validation_1-logloss:0.61926
# [67]	validation_0-logloss:0.61660	validation_1-logloss:0.61885
# [68]	validation_0-logloss:0.61612	validation_1-logloss:0.61838
# [69]	validation_0-logloss:0.61568	validation_1-logloss:0.61820
# [70]	validation_0-logloss:0.61540	validation_1-logloss:0.61805
# [71]	validation_0-logloss:0.61513	validation_1-logloss:0.61801
# [72]	validation_0-logloss:0.61491	validation_1-logloss:0.61783
# [73]	validation_0-logloss:0.61472	validation_1-logloss:0.61764
# [74]	validation_0-logloss:0.61433	validation_1-logloss:0.61725
# [75]	validation_0-logloss:0.61378	validation_1-logloss:0.61679
# [76]	validation_0-logloss:0.61369	validation_1-logloss:0.61675
# [77]	validation_0-logloss:0.61357	validation_1-logloss:0.61663
# [78]	validation_0-logloss:0.61339	validation_1-logloss:0.61669
# [79]	validation_0-logloss:0.61312	validation_1-logloss:0.61642
# [80]	validation_0-logloss:0.61299	validation_1-logloss:0.61630
# [81]	validation_0-logloss:0.61256	validation_1-logloss:0.61598
# [82]	validation_0-logloss:0.61234	validation_1-logloss:0.61596
# [83]	validation_0-logloss:0.61214	validation_1-logloss:0.61568
# [84]	validation_0-logloss:0.61188	validation_1-logloss:0.61544
# [85]	validation_0-logloss:0.61162	validation_1-logloss:0.61506
# [86]	validation_0-logloss:0.61142	validation_1-logloss:0.61504
# [87]	validation_0-logloss:0.61123	validation_1-logloss:0.61491
# [88]	validation_0-logloss:0.61091	validation_1-logloss:0.61481
# [89]	validation_0-logloss:0.61053	validation_1-logloss:0.61457
# [90]	validation_0-logloss:0.61032	validation_1-logloss:0.61437
# [91]	validation_0-logloss:0.61013	validation_1-logloss:0.61423
# [92]	validation_0-logloss:0.61002	validation_1-logloss:0.61419
# [93]	validation_0-logloss:0.60988	validation_1-logloss:0.61418
# [94]	validation_0-logloss:0.60984	validation_1-logloss:0.61421
# [95]	validation_0-logloss:0.60967	validation_1-logloss:0.61413
# [96]	validation_0-logloss:0.60959	validation_1-logloss:0.61409
# [97]	validation_0-logloss:0.60946	validation_1-logloss:0.61393
# [98]	validation_0-logloss:0.60916	validation_1-logloss:0.61396
# [99]	validation_0-logloss:0.60894	validation_1-logloss:0.61372
# [100]	validation_0-logloss:0.60877	validation_1-logloss:0.61342
# [101]	validation_0-logloss:0.60851	validation_1-logloss:0.61339
# [102]	validation_0-logloss:0.60843	validation_1-logloss:0.61333
# [103]	validation_0-logloss:0.60818	validation_1-logloss:0.61329
# [104]	validation_0-logloss:0.60802	validation_1-logloss:0.61305
# [105]	validation_0-logloss:0.60780	validation_1-logloss:0.61290
# [106]	validation_0-logloss:0.60765	validation_1-logloss:0.61285
# [107]	validation_0-logloss:0.60751	validation_1-logloss:0.61268
# [108]	validation_0-logloss:0.60737	validation_1-logloss:0.61270
# [109]	validation_0-logloss:0.60716	validation_1-logloss:0.61249
# [110]	validation_0-logloss:0.60707	validation_1-logloss:0.61248
# [111]	validation_0-logloss:0.60699	validation_1-logloss:0.61245
# [112]	validation_0-logloss:0.60691	validation_1-logloss:0.61240
# [113]	validation_0-logloss:0.60681	validation_1-logloss:0.61239
# [114]	validation_0-logloss:0.60667	validation_1-logloss:0.61207
# [115]	validation_0-logloss:0.60658	validation_1-logloss:0.61209
# [116]	validation_0-logloss:0.60649	validation_1-logloss:0.61181
# [117]	validation_0-logloss:0.60635	validation_1-logloss:0.61179
# [118]	validation_0-logloss:0.60635	validation_1-logloss:0.61182
# [119]	validation_0-logloss:0.60634	validation_1-logloss:0.61185
# [120]	validation_0-logloss:0.60632	validation_1-logloss:0.61187
# [121]	validation_0-logloss:0.60621	validation_1-logloss:0.61175
# [122]	validation_0-logloss:0.60613	validation_1-logloss:0.61171
# [123]	validation_0-logloss:0.60584	validation_1-logloss:0.61166
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [124]	validation_0-logloss:0.60573	validation_1-logloss:0.61151
# [125]	validation_0-logloss:0.60564	validation_1-logloss:0.61138
# [126]	validation_0-logloss:0.60561	validation_1-logloss:0.61140
# [127]	validation_0-logloss:0.60558	validation_1-logloss:0.61148
# [128]	validation_0-logloss:0.60554	validation_1-logloss:0.61148
# [129]	validation_0-logloss:0.60533	validation_1-logloss:0.61148
# [130]	validation_0-logloss:0.60528	validation_1-logloss:0.61144
# [131]	validation_0-logloss:0.60514	validation_1-logloss:0.61132
# [132]	validation_0-logloss:0.60503	validation_1-logloss:0.61128
# [133]	validation_0-logloss:0.60491	validation_1-logloss:0.61121
# [134]	validation_0-logloss:0.60477	validation_1-logloss:0.61126
# [135]	validation_0-logloss:0.60472	validation_1-logloss:0.61137
# [136]	validation_0-logloss:0.60451	validation_1-logloss:0.61123
# [137]	validation_0-logloss:0.60448	validation_1-logloss:0.61134
# [138]	validation_0-logloss:0.60447	validation_1-logloss:0.61129
# [139]	validation_0-logloss:0.60437	validation_1-logloss:0.61132
# [140]	validation_0-logloss:0.60419	validation_1-logloss:0.61131
# [141]	validation_0-logloss:0.60413	validation_1-logloss:0.61133
# [142]	validation_0-logloss:0.60399	validation_1-logloss:0.61145
# [143]	validation_0-logloss:0.60381	validation_1-logloss:0.61137
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.2s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.2min
# [0]	validation_0-logloss:0.67173	validation_1-logloss:0.66490
# [1]	validation_0-logloss:0.66992	validation_1-logloss:0.66318
# [2]	validation_0-logloss:0.66876	validation_1-logloss:0.66197
# [3]	validation_0-logloss:0.66745	validation_1-logloss:0.66090
# [4]	validation_0-logloss:0.66583	validation_1-logloss:0.65983
# [5]	validation_0-logloss:0.66288	validation_1-logloss:0.65684
# [6]	validation_0-logloss:0.66187	validation_1-logloss:0.65571
# [7]	validation_0-logloss:0.66061	validation_1-logloss:0.65508
# [8]	validation_0-logloss:0.65913	validation_1-logloss:0.65395
# [9]	validation_0-logloss:0.65800	validation_1-logloss:0.65308
# [10]	validation_0-logloss:0.65626	validation_1-logloss:0.65146
# [11]	validation_0-logloss:0.65528	validation_1-logloss:0.65037
# [12]	validation_0-logloss:0.65448	validation_1-logloss:0.64962
# [13]	validation_0-logloss:0.65347	validation_1-logloss:0.64868
# [14]	validation_0-logloss:0.65251	validation_1-logloss:0.64769
# [15]	validation_0-logloss:0.65102	validation_1-logloss:0.64637
# ...
# [88]	validation_0-logloss:0.60408	validation_1-logloss:0.60981
# [89]	validation_0-logloss:0.60367	validation_1-logloss:0.60974
# [90]	validation_0-logloss:0.60344	validation_1-logloss:0.60955
# [91]	validation_0-logloss:0.60327	validation_1-logloss:0.60966
# [92]	validation_0-logloss:0.60321	validation_1-logloss:0.60972
# [93]	validation_0-logloss:0.60310	validation_1-logloss:0.60977
# [94]	validation_0-logloss:0.60297	validation_1-logloss:0.60971
# [95]	validation_0-logloss:0.60292	validation_1-logloss:0.60973
# [96]	validation_0-logloss:0.60273	validation_1-logloss:0.60950
# [97]	validation_0-logloss:0.60268	validation_1-logloss:0.60944
# [98]	validation_0-logloss:0.60234	validation_1-logloss:0.60943
# [99]	validation_0-logloss:0.60205	validation_1-logloss:0.60917
# [100]	validation_0-logloss:0.60177	validation_1-logloss:0.60883
# [101]	validation_0-logloss:0.60148	validation_1-logloss:0.60877
# [102]	validation_0-logloss:0.60133	validation_1-logloss:0.60891
# [103]	validation_0-logloss:0.60107	validation_1-logloss:0.60880
# [104]	validation_0-logloss:0.60098	validation_1-logloss:0.60875
# [105]	validation_0-logloss:0.60077	validation_1-logloss:0.60862
# [106]	validation_0-logloss:0.60067	validation_1-logloss:0.60832
# [107]	validation_0-logloss:0.60045	validation_1-logloss:0.60812
# [108]	validation_0-logloss:0.60038	validation_1-logloss:0.60815
# [109]	validation_0-logloss:0.60012	validation_1-logloss:0.60798
# [110]	validation_0-logloss:0.59996	validation_1-logloss:0.60795
# [111]	validation_0-logloss:0.59984	validation_1-logloss:0.60795
# [112]	validation_0-logloss:0.59972	validation_1-logloss:0.60782
# [113]	validation_0-logloss:0.59964	validation_1-logloss:0.60783
# [114]	validation_0-logloss:0.59945	validation_1-logloss:0.60773
# [115]	validation_0-logloss:0.59938	validation_1-logloss:0.60774
# [116]	validation_0-logloss:0.59920	validation_1-logloss:0.60764
# [117]	validation_0-logloss:0.59913	validation_1-logloss:0.60766
# [118]	validation_0-logloss:0.59909	validation_1-logloss:0.60772
# [119]	validation_0-logloss:0.59906	validation_1-logloss:0.60765
# [120]	validation_0-logloss:0.59892	validation_1-logloss:0.60739
# [121]	validation_0-logloss:0.59876	validation_1-logloss:0.60726
# [122]	validation_0-logloss:0.59868	validation_1-logloss:0.60728
# [123]	validation_0-logloss:0.59841	validation_1-logloss:0.60722
# [124]	validation_0-logloss:0.59835	validation_1-logloss:0.60733
# [125]	validation_0-logloss:0.59818	validation_1-logloss:0.60722
# [126]	validation_0-logloss:0.59804	validation_1-logloss:0.60718
# [127]	validation_0-logloss:0.59804	validation_1-logloss:0.60707
# [128]	validation_0-logloss:0.59796	validation_1-logloss:0.60698
# [129]	validation_0-logloss:0.59772	validation_1-logloss:0.60695
# [130]	validation_0-logloss:0.59764	validation_1-logloss:0.60695
# [131]	validation_0-logloss:0.59746	validation_1-logloss:0.60677
# [132]	validation_0-logloss:0.59737	validation_1-logloss:0.60681
# [133]	validation_0-logloss:0.59716	validation_1-logloss:0.60663
# [134]	validation_0-logloss:0.59702	validation_1-logloss:0.60678
# [135]	validation_0-logloss:0.59701	validation_1-logloss:0.60679
# [136]	validation_0-logloss:0.59678	validation_1-logloss:0.60658
# [137]	validation_0-logloss:0.59669	validation_1-logloss:0.60661
# [138]	validation_0-logloss:0.59670	validation_1-logloss:0.60676
# [139]	validation_0-logloss:0.59667	validation_1-logloss:0.60675
# [140]	validation_0-logloss:0.59650	validation_1-logloss:0.60688
# [141]	validation_0-logloss:0.59648	validation_1-logloss:0.60694
# [142]	validation_0-logloss:0.59617	validation_1-logloss:0.60698
# [143]	validation_0-logloss:0.59599	validation_1-logloss:0.60696
# [144]	validation_0-logloss:0.59589	validation_1-logloss:0.60710
# [145]	validation_0-logloss:0.59582	validation_1-logloss:0.60710
# [146]	validation_0-logloss:0.59578	validation_1-logloss:0.60718
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   0.2s
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Pipeline] ..... (step 1 of 2) Processing Preprocessing, total= 1.8min
# [0]	validation_0-logloss:0.67134	validation_1-logloss:0.66470
# [1]	validation_0-logloss:0.66910	validation_1-logloss:0.66276
# [2]	validation_0-logloss:0.66728	validation_1-logloss:0.66138
# [3]	validation_0-logloss:0.66577	validation_1-logloss:0.66024
# [4]	validation_0-logloss:0.66371	validation_1-logloss:0.65875
# [5]	validation_0-logloss:0.66042	validation_1-logloss:0.65590
# [6]	validation_0-logloss:0.65900	validation_1-logloss:0.65449
# [7]	validation_0-logloss:0.65748	validation_1-logloss:0.65383
# [8]	validation_0-logloss:0.65586	validation_1-logloss:0.65269
# [9]	validation_0-logloss:0.65417	validation_1-logloss:0.65128
# /home/joe/Programs/GitHub/automl-helpers-private/venv/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [10]	validation_0-logloss:0.65199	validation_1-logloss:0.64978
# [11]	validation_0-logloss:0.65065	validation_1-logloss:0.64869
# [12]	validation_0-logloss:0.64955	validation_1-logloss:0.64776
# [13]	validation_0-logloss:0.64842	validation_1-logloss:0.64701
# [14]	validation_0-logloss:0.64713	validation_1-logloss:0.64588
# [15]	validation_0-logloss:0.64544	validation_1-logloss:0.64437
# [16]	validation_0-logloss:0.64454	validation_1-logloss:0.64380
# [17]	validation_0-logloss:0.64340	validation_1-logloss:0.64277
# [18]	validation_0-logloss:0.64226	validation_1-logloss:0.64180
# [19]	validation_0-logloss:0.64140	validation_1-logloss:0.64116
# [20]	validation_0-logloss:0.63877	validation_1-logloss:0.63879
# [21]	validation_0-logloss:0.63770	validation_1-logloss:0.63795
# [22]	validation_0-logloss:0.63597	validation_1-logloss:0.63641
# [23]	validation_0-logloss:0.63475	validation_1-logloss:0.63527
# [24]	validation_0-logloss:0.63382	validation_1-logloss:0.63446
# [25]	validation_0-logloss:0.63270	validation_1-logloss:0.63363
# [26]	validation_0-logloss:0.63196	validation_1-logloss:0.63314
# [27]	validation_0-logloss:0.63083	validation_1-logloss:0.63214
# [28]	validation_0-logloss:0.62999	validation_1-logloss:0.63156
# [29]	validation_0-logloss:0.62893	validation_1-logloss:0.63072
# [30]	validation_0-logloss:0.62819	validation_1-logloss:0.63036
# [31]	validation_0-logloss:0.62737	validation_1-logloss:0.62979
# [32]	validation_0-logloss:0.62669	validation_1-logloss:0.62955
# [33]	validation_0-logloss:0.62578	validation_1-logloss:0.62886
# [34]	validation_0-logloss:0.62495	validation_1-logloss:0.62818
# [35]	validation_0-logloss:0.62435	validation_1-logloss:0.62788
# [36]	validation_0-logloss:0.62286	validation_1-logloss:0.62686
# [37]	validation_0-logloss:0.62139	validation_1-logloss:0.62584
# [38]	validation_0-logloss:0.62049	validation_1-logloss:0.62495
# [39]	validation_0-logloss:0.61971	validation_1-logloss:0.62420
# [40]	validation_0-logloss:0.61891	validation_1-logloss:0.62344
# [41]	validation_0-logloss:0.61847	validation_1-logloss:0.62309
# [42]	validation_0-logloss:0.61792	validation_1-logloss:0.62290
# [43]	validation_0-logloss:0.61739	validation_1-logloss:0.62263
# [44]	validation_0-logloss:0.61696	validation_1-logloss:0.62232
# [45]	validation_0-logloss:0.61574	validation_1-logloss:0.62153
# [46]	validation_0-logloss:0.61494	validation_1-logloss:0.62082
# [47]	validation_0-logloss:0.61427	validation_1-logloss:0.62036
# [48]	validation_0-logloss:0.61324	validation_1-logloss:0.61965
# [49]	validation_0-logloss:0.61273	validation_1-logloss:0.61940
# [50]	validation_0-logloss:0.61223	validation_1-logloss:0.61934
# [51]	validation_0-logloss:0.61174	validation_1-logloss:0.61914
# [52]	validation_0-logloss:0.61130	validation_1-logloss:0.61897
# [53]	validation_0-logloss:0.61028	validation_1-logloss:0.61847
# [54]	validation_0-logloss:0.60985	validation_1-logloss:0.61833
# [55]	validation_0-logloss:0.60910	validation_1-logloss:0.61778
# [56]	validation_0-logloss:0.60848	validation_1-logloss:0.61743
# [57]	validation_0-logloss:0.60760	validation_1-logloss:0.61676
# [58]	validation_0-logloss:0.60668	validation_1-logloss:0.61628
# [59]	validation_0-logloss:0.60636	validation_1-logloss:0.61631
# [60]	validation_0-logloss:0.60591	validation_1-logloss:0.61604
# [61]	validation_0-logloss:0.60534	validation_1-logloss:0.61556
# [62]	validation_0-logloss:0.60483	validation_1-logloss:0.61524
# [63]	validation_0-logloss:0.60405	validation_1-logloss:0.61467
# [64]	validation_0-logloss:0.60345	validation_1-logloss:0.61439
# [65]	validation_0-logloss:0.60315	validation_1-logloss:0.61435
# [66]	validation_0-logloss:0.60241	validation_1-logloss:0.61396
# [67]	validation_0-logloss:0.60166	validation_1-logloss:0.61350
# [68]	validation_0-logloss:0.60106	validation_1-logloss:0.61328
# [69]	validation_0-logloss:0.60052	validation_1-logloss:0.61301
# [70]	validation_0-logloss:0.60007	validation_1-logloss:0.61283
# [71]	validation_0-logloss:0.59970	validation_1-logloss:0.61286
# [72]	validation_0-logloss:0.59935	validation_1-logloss:0.61277
# [73]	validation_0-logloss:0.59902	validation_1-logloss:0.61253
# [74]	validation_0-logloss:0.59847	validation_1-logloss:0.61222
# [75]	validation_0-logloss:0.59774	validation_1-logloss:0.61170
# [76]	validation_0-logloss:0.59746	validation_1-logloss:0.61172
# [77]	validation_0-logloss:0.59704	validation_1-logloss:0.61165
# [78]	validation_0-logloss:0.59684	validation_1-logloss:0.61166
# [79]	validation_0-logloss:0.59643	validation_1-logloss:0.61133
# [80]	validation_0-logloss:0.59614	validation_1-logloss:0.61132
# [81]	validation_0-logloss:0.59556	validation_1-logloss:0.61098
# [82]	validation_0-logloss:0.59517	validation_1-logloss:0.61088
# [83]	validation_0-logloss:0.59475	validation_1-logloss:0.61065
# [84]	validation_0-logloss:0.59436	validation_1-logloss:0.61042
# [85]	validation_0-logloss:0.59398	validation_1-logloss:0.61005
# [86]	validation_0-logloss:0.59368	validation_1-logloss:0.61008
# [87]	validation_0-logloss:0.59342	validation_1-logloss:0.60995
# [88]	validation_0-logloss:0.59302	validation_1-logloss:0.60989
# [89]	validation_0-logloss:0.59255	validation_1-logloss:0.60961
# [90]	validation_0-logloss:0.59219	validation_1-logloss:0.60940
# [91]	validation_0-logloss:0.59188	validation_1-logloss:0.60932
# [92]	validation_0-logloss:0.59158	validation_1-logloss:0.60913
# [93]	validation_0-logloss:0.59131	validation_1-logloss:0.60911
# [94]	validation_0-logloss:0.59095	validation_1-logloss:0.60903
# [95]	validation_0-logloss:0.59064	validation_1-logloss:0.60901
# [96]	validation_0-logloss:0.59040	validation_1-logloss:0.60884
# [97]	validation_0-logloss:0.59008	validation_1-logloss:0.60884
# [98]	validation_0-logloss:0.58973	validation_1-logloss:0.60880
# [99]	validation_0-logloss:0.58934	validation_1-logloss:0.60848
# [100]	validation_0-logloss:0.58897	validation_1-logloss:0.60822
# [101]	validation_0-logloss:0.58860	validation_1-logloss:0.60813
# [102]	validation_0-logloss:0.58827	validation_1-logloss:0.60807
# [103]	validation_0-logloss:0.58787	validation_1-logloss:0.60801
# [104]	validation_0-logloss:0.58750	validation_1-logloss:0.60803
# [105]	validation_0-logloss:0.58722	validation_1-logloss:0.60788
# [106]	validation_0-logloss:0.58679	validation_1-logloss:0.60762
# [107]	validation_0-logloss:0.58647	validation_1-logloss:0.60748
# [108]	validation_0-logloss:0.58624	validation_1-logloss:0.60753
# [109]	validation_0-logloss:0.58590	validation_1-logloss:0.60732
# [110]	validation_0-logloss:0.58569	validation_1-logloss:0.60722
# [111]	validation_0-logloss:0.58547	validation_1-logloss:0.60717
# [112]	validation_0-logloss:0.58526	validation_1-logloss:0.60707
# [113]	validation_0-logloss:0.58510	validation_1-logloss:0.60701
# [114]	validation_0-logloss:0.58481	validation_1-logloss:0.60681
# [115]	validation_0-logloss:0.58467	validation_1-logloss:0.60692
# [116]	validation_0-logloss:0.58431	validation_1-logloss:0.60653
# [117]	validation_0-logloss:0.58414	validation_1-logloss:0.60658
# [118]	validation_0-logloss:0.58392	validation_1-logloss:0.60643
# [119]	validation_0-logloss:0.58374	validation_1-logloss:0.60644
# [120]	validation_0-logloss:0.58342	validation_1-logloss:0.60627
# [121]	validation_0-logloss:0.58320	validation_1-logloss:0.60628
# [122]	validation_0-logloss:0.58303	validation_1-logloss:0.60625
# [123]	validation_0-logloss:0.58268	validation_1-logloss:0.60614
# [124]	validation_0-logloss:0.58254	validation_1-logloss:0.60617
# [125]	validation_0-logloss:0.58223	validation_1-logloss:0.60603
# [126]	validation_0-logloss:0.58191	validation_1-logloss:0.60587
# [127]	validation_0-logloss:0.58155	validation_1-logloss:0.60588
# [128]	validation_0-logloss:0.58127	validation_1-logloss:0.60580
# [129]	validation_0-logloss:0.58084	validation_1-logloss:0.60562
# [130]	validation_0-logloss:0.58071	validation_1-logloss:0.60562
# [131]	validation_0-logloss:0.58048	validation_1-logloss:0.60547
# [132]	validation_0-logloss:0.58029	validation_1-logloss:0.60543
# [133]	validation_0-logloss:0.57996	validation_1-logloss:0.60529
# [134]	validation_0-logloss:0.57965	validation_1-logloss:0.60522
# [135]	validation_0-logloss:0.57928	validation_1-logloss:0.60523
# [136]	validation_0-logloss:0.57897	validation_1-logloss:0.60502
# [137]	validation_0-logloss:0.57879	validation_1-logloss:0.60502
# [138]	validation_0-logloss:0.57863	validation_1-logloss:0.60499
# [139]	validation_0-logloss:0.57850	validation_1-logloss:0.60503
# [140]	validation_0-logloss:0.57807	validation_1-logloss:0.60492
# [141]	validation_0-logloss:0.57796	validation_1-logloss:0.60494
# [142]	validation_0-logloss:0.57773	validation_1-logloss:0.60493
# [143]	validation_0-logloss:0.57749	validation_1-logloss:0.60485
# [144]	validation_0-logloss:0.57717	validation_1-logloss:0.60496
# [145]	validation_0-logloss:0.57703	validation_1-logloss:0.60505
# [146]	validation_0-logloss:0.57669	validation_1-logloss:0.60489
# [147]	validation_0-logloss:0.57646	validation_1-logloss:0.60501
# [148]	validation_0-logloss:0.57634	validation_1-logloss:0.60508
# [149]	validation_0-logloss:0.57607	validation_1-logloss:0.60510
# [150]	validation_0-logloss:0.57580	validation_1-logloss:0.60509
# [151]	validation_0-logloss:0.57554	validation_1-logloss:0.60488
# [152]	validation_0-logloss:0.57531	validation_1-logloss:0.60491
# [153]	validation_0-logloss:0.57502	validation_1-logloss:0.60468
# [154]	validation_0-logloss:0.57473	validation_1-logloss:0.60468
# [155]	validation_0-logloss:0.57449	validation_1-logloss:0.60449
# [156]	validation_0-logloss:0.57424	validation_1-logloss:0.60460
# [157]	validation_0-logloss:0.57415	validation_1-logloss:0.60461
# [158]	validation_0-logloss:0.57406	validation_1-logloss:0.60456
# [159]	validation_0-logloss:0.57390	validation_1-logloss:0.60463
# [160]	validation_0-logloss:0.57371	validation_1-logloss:0.60454
# [161]	validation_0-logloss:0.57359	validation_1-logloss:0.60449
# [162]	validation_0-logloss:0.57345	validation_1-logloss:0.60455
# [163]	validation_0-logloss:0.57338	validation_1-logloss:0.60451
# [164]	validation_0-logloss:0.57329	validation_1-logloss:0.60450
# [165]	validation_0-logloss:0.57311	validation_1-logloss:0.60455
# [166]	validation_0-logloss:0.57299	validation_1-logloss:0.60460
# [167]	validation_0-logloss:0.57281	validation_1-logloss:0.60451
# [168]	validation_0-logloss:0.57274	validation_1-logloss:0.60451
# [169]	validation_0-logloss:0.57249	validation_1-logloss:0.60459
# [170]	validation_0-logloss:0.57232	validation_1-logloss:0.60466
# [171]	validation_0-logloss:0.57198	validation_1-logloss:0.60459
# [Pipeline] ............... (step 2 of 2) Processing gbm, total=   1.0s
# Best parameter (CV score=0.658):
# {'gbm__max_depth': 4}

# %%
search.cv_results_
# Out:
# {'mean_fit_time': array([74.55978432, 74.19890904]),
#  'std_fit_time': array([2.98052242, 1.57871439]),
#  'mean_score_time': array([0.09182014, 0.07949972]),
#  'std_score_time': array([0.01702511, 0.01414406]),
#  'param_gbm__max_depth': masked_array(data=[3, 4],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'gbm__max_depth': 3}, {'gbm__max_depth': 4}],
#  'split0_test_score': array([0.660625, 0.65875 ]),
#  'split1_test_score': array([0.645   , 0.646875]),
#  'split2_test_score': array([0.6675, 0.67  ]),
#  'split3_test_score': array([0.664375, 0.665625]),
#  'split4_test_score': array([0.64875, 0.65   ]),
#  'mean_test_score': array([0.65725, 0.65825]),
#  'std_test_score': array([0.00882645, 0.00883353]),
#  'rank_test_score': array([2, 1], dtype=int32)}

# %%
roc_auc_score(y_test,search.best_estimator_.predict_proba(X_test[num_features+[fff for fff in feature_lists_2]])[:,1])
# Out:
# 0.7022059912572838

# %%
joblib.dump(search.best_estimator_, 'pipeline_xgb.pkl')
# Out:
# ['pipeline_xgb.pkl']

# %%
type(search.best_estimator_)
# Out:
# sklearn.pipeline.Pipeline

# %%
dict_file=[{'feature_list':num_features+[fff for fff in feature_lists_2]},{'model_file':"pipeline_xgb.pkl"}]
with open(r'model_file.yaml', 'w') as file:
    documents = yaml.dump(dict_file, file)

# %%
with open(r'model_file.yaml') as file:
    documents = yaml.full_load(file)
    print(documents)

    for ddd in documents:
        print(ddd.keys())
# Out:
# [{'feature_list': ['number_inpatient', 'number_diagnoses', 'num_lab_procedures', 'num_medications', 'time_in_hospital', 'num_procedures', 'number_outpatient', 'number_emergency', 'medical_specialty', 'admission_source_id', 'diag_3_desc', 'diag_1_desc', 'admission_type_id', 'diag_2_desc', 'age', 'discharge_disposition_id']}, {'model_file': 'pipeline_xgb.pkl'}]
# dict_keys(['feature_list'])
# dict_keys(['model_file'])

# %%
mmm=search.best_estimator_.steps[-1][1]
mmm.best_iteration
# Out:
# 161

# %%
final_layer=search.best_estimator_[-1]
final_layer
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, grow_policy=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=0, max_depth=4,
#               max_leaves=None, min_child_weight=1, missing=-99999,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, random_state=0, ...)

# %%
for c in range(len(final_layer.feature_importances_)):
    print(X_train[num_features+[fff for fff in feature_lists_2]].columns[c]+": "+str(final_layer.feature_importances_[c]))
# Out:
# number_inpatient: 0.19275641
# number_diagnoses: 0.11179899
# num_lab_procedures: 0.04194721
# num_medications: 0.028055694
# time_in_hospital: 0.028323285
# num_procedures: 0.026455224
# number_outpatient: 0.10191794
# number_emergency: 0.06134672
# medical_specialty: 0.06294054
# admission_source_id: 0.042034157
# diag_3_desc: 0.03731555
# diag_1_desc: 0.041612193
# admission_type_id: 0.03793671
# diag_2_desc: 0.039701574
# age: 0.03883462
# discharge_disposition_id: 0.10702311

# %%
X_test[num_features+[fff for fff in feature_lists_2]]
# Out:
#       number_inpatient  number_diagnoses  num_lab_procedures  num_medications  \
# 2374                 0                 9                  62               40
# 1784                 0                 5                   1               16
# 6301                 0                 9                  54               14
# 1600                 0                 5                  45               36
# 7920                 1                 9                  53               14
# ...                ...               ...                 ...              ...
# 8623                 0                 9                   4               13
# 5928                 0                 9                  50               15
# 6714                 0                 6                  64               13
# 5885                 0                 7                  25                7
# 7289                 0                 7                  45               16
#
#       time_in_hospital  num_procedures  number_outpatient  number_emergency  \
# 2374                14               6                  0                 0
# 1784                 3               3                  6                 0
# 6301                 7               0                  0                 0
# 1600                 4               5                  0                 0
# 7920                12               0                  0                 0
# ...                ...             ...                ...               ...
# 8623                 1               0                  0                 0
# 5928                 3               0                  0                 0
# 6714                 3               0                  0                 0
# 5885                 3               0                  0                 0
# 7289                14               2                  0                 0
#
#      medical_specialty                             admission_source_id  \
# 2374  InternalMedicine                                  Emergency Room
# 1784                 ?                                             NaN
# 6301  InternalMedicine                                  Emergency Room
# 1600                 ?                              Physician Referral
# 7920                 ?      Transfer from another health care facility
# ...                ...                                             ...
# 8623                 ?                                  Emergency Room
# 5928                 ?                                  Emergency Room
# 6714                 ?                                  Emergency Room
# 5885  Emergency/Trauma                                  Emergency Room
# 7289                 ?  Transfer from a Skilled Nursing Facility (SNF)
#
#                                             diag_3_desc  \
# 2374                                 Pulmonary collapse
# 1784                   Malignant essential hypertension
# 6301  Coronary atherosclerosis of unspecified type o...
# 1600  Diabetes mellitus without mention of complicat...
# 7920                           Cerebral atherosclerosis
# ...                                                 ...
# 8623                                           Headache
# 5928  Hypertensive chronic kidney disease, malignant...
# 6714                        Alteration of consciousness
# 5885                        Chronic maxillary sinusitis
# 7289                   Pressure ulcer, unspecified site
#
#                                             diag_1_desc admission_type_id  \
# 2374  Diabetes with ketoacidosis, type II or unspeci...         Emergency
# 1784                               Obesity, unspecified     Not Available
# 6301                          Simple chronic bronchitis         Emergency
# 1600  Coronary atherosclerosis of unspecified type o...          Elective
# 7920                 Care involving breathing exercises          Elective
# ...                                                 ...               ...
# 8623               Respiratory abnormality, unspecified         Emergency
# 5928                           Streptococcal septicemia            Urgent
# 6714  Acute myocardial infarction of anterolateral w...         Emergency
# 5885            Paroxysmal supraventricular tachycardia          Elective
# 7289                           Atherosclerosis of aorta         Emergency
#
#                                             diag_2_desc      age  \
# 2374            Paroxysmal supraventricular tachycardia  [40-50)
# 1784                          Pure hypercholesterolemia  [50-60)
# 6301  Coronary atherosclerosis of unspecified type o...  [80-90)
# 1600                 Postmyocardial infarction syndrome  [50-60)
# 7920  Cerebral thrombosis without mention of cerebra...  [60-70)
# ...                                                 ...      ...
# 8623        Urinary tract infection, site not specified  [70-80)
# 5928                               Acute kidney failure  [60-70)
# 6714              Congestive heart failure, unspecified  [80-90)
# 5885                           Acute laryngopharyngitis  [50-60)
# 7289              Acute osteomyelitis, site unspecified  [50-60)
#
#                                discharge_disposition_id
# 2374                                 Discharged to home
# 1784                                 Discharged to home
# 6301  Discharged/transferred to another  type of inp...
# 1600                                                NaN
# 7920  Discharged/transferred to home with home healt...
# ...                                                 ...
# 8623                      Discharged/transferred to ICF
# 5928  Discharged/transferred to another short term h...
# 6714                      Discharged/transferred to SNF
# 5885                                 Discharged to home
# 7289                      Discharged/transferred to SNF
#
# [2000 rows x 16 columns]

# %%
#get test set text predictions
test_pred=search.predict_proba(X_test[num_features+[fff for fff in feature_lists_2]])

# %%
test_pred=search.best_estimator_.predict_proba(X_test[num_features+[fff for fff in feature_lists_2]])

# %%
roc_auc_score(y_test,test_pred[:,1])
# Out:
# 0.7022059912572838

# %%
log_loss(y_test, test_pred[:,1])
# Out:
# 0.6045116858714573
